# %%
import os
import pybedtools
import pandas as pd
import numpy as np
import glob
import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
#import pybedtools
import random
from Bio import SeqIO
from Bio.Seq import Seq
import pysam

# %%
custom_palette = ['#C8ADC0', '#FE9920', '#028090', '#151E3F', '#7E1F86','#F27D18']

# %%
sns_palette = sns.color_palette(custom_palette)

# %%
sns_palette
# Out:
# [(0.7843137254901961, 0.6784313725490196, 0.7529411764705882),
#  (0.996078431372549, 0.6, 0.12549019607843137),
#  (0.00784313725490196, 0.5019607843137255, 0.5647058823529412),
#  (0.08235294117647059, 0.11764705882352941, 0.24705882352941178),
#  (0.49411764705882355, 0.12156862745098039, 0.5254901960784314),
#  (0.9490196078431372, 0.49019607843137253, 0.09411764705882353)]

# %%
sns.set_palette(sns_palette)

# %% [markdown]
# This notebook incorporates Genes and Transcripts with 0 edits and LM to get signal over background

# %%
working_dir = '/tscc/nfs/home/pjaganna1/projects/STAMP/stamp_v3_pipeline'

# %%
fig_path = '/tscc/nfs/home/pjaganna1/projects/STAMP/stamp_v3_pipeline/notebooks/figs/'

# %%
sample_dict_wt = {'rep1' : '231_NT_rep1', 
               'rep2' : '231_NT_rep2'}
sample_dict_cocl2 = {'rep1' : '231_cocl2_rep1',
               'rep2' : '231_cocl2_rep2'}

# %%
output_dir = '/tscc/nfs/home/pjaganna1/projects/STAMP/stamp_v3_pipeline'

# %%
gtf_file = "/tscc/nfs/home/pjaganna1/projects/STAMP/stamp_v3_pipeline/refs/hg38/gencode.v38.annotation.gtf" # Replace with your GTF file path

# %%
glob.glob(os.path.join(working_dir, f'{sample_dict_wt["rep1"]}/output_dir/read_level_edits_ct/*edits_*.bed'))[:5]
# Out:
# ['/tscc/nfs/home/pjaganna1/projects/STAMP/stamp_v3_pipeline/231_NT_rep1/output_dir/read_level_edits_ct/split_bam_1_103_read_level_edits_3utr.bed',
#  '/tscc/nfs/home/pjaganna1/projects/STAMP/stamp_v3_pipeline/231_NT_rep1/output_dir/read_level_edits_ct/split_bam_1_37_read_level_edits_3utr.bed',
#  '/tscc/nfs/home/pjaganna1/projects/STAMP/stamp_v3_pipeline/231_NT_rep1/output_dir/read_level_edits_ct/split_bam_2_0_read_level_edits_5utr.bed',
#  '/tscc/nfs/home/pjaganna1/projects/STAMP/stamp_v3_pipeline/231_NT_rep1/output_dir/read_level_edits_ct/split_bam_2_34_read_level_edits_5utr.bed',
#  '/tscc/nfs/home/pjaganna1/projects/STAMP/stamp_v3_pipeline/231_NT_rep1/output_dir/read_level_edits_ct/split_bam_1_94_read_level_edits_5utr.bed']

# %%
#pysam.view("-c", os.path.join(working_dir, f'{sample_dict_rps2[keys]}/input_dir/{sample_dict_rps2[keys]}.flnc.aligned.readfiltered.sorted.bam'))

# %%
total_mapped_reads = {}
for keys in ['rep1', 'rep2']:
    total_mapped_reads[sample_dict_wt[keys]] = int(pysam.view("-c", os.path.join(working_dir, f'{sample_dict_wt[keys]}/input_dir/{sample_dict_wt[keys]}.flnc.aligned.readfiltered.sorted.bam')).strip('\n'))
    total_mapped_reads[sample_dict_cocl2[keys]] = int(pysam.view("-c", os.path.join(working_dir, f'{sample_dict_cocl2[keys]}/input_dir/{sample_dict_cocl2[keys]}.flnc.aligned.readfiltered.sorted.bam')).strip('\n'))

# %%
# sns.set_style('white')
# pd.DataFrame.from_dict(total_mapped_reads, orient='index').plot.bar()

# %%
gtf_len_df = pd.read_csv(gtf_file, sep='\t', header=None, comment='#')
# # Filter rows with the "gene" feature
gtf_len_df = gtf_len_df[gtf_len_df[2] == 'gene']
# # Calculate gene lengths
gtf_len_df['gene_length'] = gtf_len_df[4] - gtf_len_df[3] + 1
# # Create a dictionary with gene names as keys and gene lengths as values
gtf_len_df['gene_id'] = gtf_len_df[8].str.extract('gene_id "([^"]+)"')
gene_length_dict = gtf_len_df.set_index('gene_id')['gene_length'].to_dict()
gtf_len_df['gene_name'] = gtf_len_df[8].str.extract('gene_name "([^"]+)"')
gene_name_length_dict = gtf_len_df.set_index('gene_name')['gene_length'].to_dict()
gene_id_to_name_dict = gtf_len_df.set_index('gene_id')['gene_name'].to_dict()

# %%
gtf_transcript_to_gene_df = pd.read_csv(gtf_file, sep='\t', header=None, comment='#')
gtf_transcript_to_gene_df = gtf_transcript_to_gene_df[gtf_transcript_to_gene_df[2] == 'transcript']
gtf_transcript_to_gene_df['gene_id'] = gtf_transcript_to_gene_df[8].str.extract('gene_id "([^"]+)"')
gtf_transcript_to_gene_df['transcript_id'] = gtf_transcript_to_gene_df[8].str.extract('transcript_id "([^"]+)"')
gtf_transcript_to_gene_df['transcript_length'] = gtf_transcript_to_gene_df[4] - gtf_transcript_to_gene_df[3]

# %%
gtf_transcript_to_gene_dict = dict(zip(gtf_transcript_to_gene_df.transcript_id, gtf_transcript_to_gene_df.gene_id))

# %%
gtf_transcript_to_length_dict = dict(zip(gtf_transcript_to_gene_df.transcript_id, gtf_transcript_to_gene_df.transcript_length))

# %%
feature_counts={}
for rep in ['rep1', 'rep2']:
    for sample_dict in [sample_dict_wt, sample_dict_cocl2]:
        counts_table = pd.read_csv(f'/tscc/nfs/home/pjaganna1/projects/STAMP/stamp_v3_pipeline/{sample_dict[rep]}/output_dir/feature_counts/exon_counts.txt', comment='#', sep='\t', usecols=['Geneid', 'Length',f'/home/pjaganna1/scratch/stamp_v3_pipeline/{sample_dict[rep]}/input_dir/{sample_dict[rep]}.flnc.aligned.readfiltered.sorted.bam' ])
        counts_table = counts_table.rename(columns={f'/home/pjaganna1/scratch/stamp_v3_pipeline/{sample_dict[rep]}/input_dir/{sample_dict[rep]}.flnc.aligned.readfiltered.sorted.bam': f'{sample_dict[rep]}'})
        counts_table = counts_table[counts_table[f'{sample_dict[rep]}'] >=20]
        counts_table[f'{sample_dict[rep]}_RPKM'] = counts_table.apply(lambda x: (x[f'{sample_dict[rep]}'])/((counts_table[f'{sample_dict[rep]}'].sum()/1000000.)*(x['Length']/1000.)), axis=1)
        #counts_table[f'{sample_dict[rep]}_RPKM'] = (counts_table[f'{sample_dict[rep]}'] * 1e6) / (counts_table[f'{sample_dict[rep]}'].sum() * (counts_table['Length'] / 1000))
        feature_counts[f'{sample_dict[rep]}'] = counts_table

# %%
feature_counts['231_NT_rep1']
# Out:
#                    Geneid  Length  231_NT_rep1  231_NT_rep1_RPKM
# 19      ENSG00000279457.4    1397          179        112.509932
# 63     ENSG00000187961.14    3402           22          5.678356
# 67     ENSG00000188290.11    1118           29         22.776681
# 68     ENSG00000187608.10     867          102        103.303565
# 76     ENSG00000131591.18    6322           82         11.389210
# ...                   ...     ...          ...               ...
# 60634   ENSG00000198938.2     784          232        259.840090
# 60636   ENSG00000198840.2     346           77        195.410935
# 60639   ENSG00000198886.2    1378          791        504.035937
# 60643   ENSG00000198786.2    1812          247        119.694170
# 60646   ENSG00000198727.2    1141         2781       2140.176451
#
# [5905 rows x 4 columns]

# %%
# for g in expressed_genes:
#     print(g)

# %%
transcript_counts={}
for rep in ['rep1', 'rep2']:
    for sample_dict in [sample_dict_wt, sample_dict_cocl2]:
        transcript_counts_table = pd.read_csv(f'/tscc/nfs/home/pjaganna1/projects/STAMP/stamp_v3_pipeline/{sample_dict[rep]}/output_dir/{sample_dict[rep]}_isoquant/{sample_dict[rep]}/{sample_dict[rep]}.transcript_counts.tsv', comment='#', sep='\t', header=None)
        transcript_counts_table = transcript_counts_table.rename(columns={0:'transcript_id', 1: f'{sample_dict[rep]}_count'})
        transcript_counts_table['Length'] = transcript_counts_table.transcript_id.map(gtf_transcript_to_length_dict)
        transcript_counts_table = transcript_counts_table[transcript_counts_table[f'{sample_dict[rep]}_count'] >=20]
        transcript_counts_table[f'{sample_dict[rep]}_RPKM'] = transcript_counts_table.apply(lambda x: (x[f'{sample_dict[rep]}_count'])/((transcript_counts_table[f'{sample_dict[rep]}_count'].sum()/1000000.)*(x['Length']/1000.)), axis=1)
        transcript_counts[f'{sample_dict[rep]}'] = transcript_counts_table.set_index('transcript_id')

# %%
gene_counts = {}
for key in transcript_counts:
    gene_count_df=transcript_counts[key].copy()
    gene_count_df['gene_id'] = gene_count_df.index.map(gtf_transcript_to_gene_dict)
    gene_count_df = gene_count_df[[f'{key}_count', 'gene_id']].groupby('gene_id').sum()
    gene_count_df = gene_count_df.rename(columns={f'{key}_count' : f'{key}'})
    gene_count_df['Length'] = gene_count_df.index.map(gene_length_dict)
    gene_count_df[f'{key}_RPKM'] = gene_count_df.apply(lambda x: (x[f'{key}'])/((gene_count_df[f'{key}'].sum()/1000000.)*(x['Length']/1000.)), axis=1)
    gene_count_df = gene_count_df[gene_count_df[key] >=20]
    gene_count_df = gene_count_df.reset_index().rename(columns={'gene_id' : 'Geneid'})

    gene_counts[key] = gene_count_df

# %%
gene_counts.keys()
# Out:
# dict_keys(['231_NT_rep1', '231_cocl2_rep1', '231_NT_rep2', '231_cocl2_rep2'])

# %%
deseq2_gene_count_matrix = pd.DataFrame()
for key in sorted(gene_counts):
    deseq2_gene_count_matrix = pd.concat([deseq2_gene_count_matrix, gene_counts[key][['Geneid', key]].set_index('Geneid')], axis=1)
deseq2_gene_count_matrix = deseq2_gene_count_matrix.dropna()

# %%
deseq2_gene_count_matrix.head()
# Out:
#                     231_NT_rep1  231_NT_rep2  231_cocl2_rep1  231_cocl2_rep2
# Geneid
# ENSG00000000003.15        113.0         87.0            58.0            76.0
# ENSG00000000419.14         39.0         54.0            46.0            44.0
# ENSG00000001036.14        371.0        557.0           429.0           406.0
# ENSG00000001461.17         49.0         48.0            59.0            49.0
# ENSG00000001497.18         22.0         24.0            23.0            27.0

# %%
#deseq2_gene_count_matrix.to_csv('all_sample_counts_matrix_gene_isoquant.csv')

# %%
expressed_genes = list(deseq2_gene_count_matrix.index.map(gene_id_to_name_dict))

# %%
## Checking HIF1A
# print(gene_counts['231_NT_rep1'].loc['ENSG00000100644.17'])
# print(gene_counts['231_NT_rep2'].loc['ENSG00000100644.17'])
# print(gene_counts['231_cocl2_rep1'].loc['ENSG00000100644.17'])
# print(gene_counts['231_cocl2_rep2'].loc['ENSG00000100644.17'])

# %% [markdown]
# #### Get Read Level Edits

# %%
def concat_splits_all_edits(sample_dict):
    '''concatenate all position level edits from all splits and reps and store as dictionary'''
    concat_edits = {}
    for key in sample_dict:
        print(key)
        read_level_edits_df = pd.DataFrame()
        empty_splits = []
        for p in tqdm.tqdm(glob.glob(os.path.join(working_dir, f'{sample_dict[key]}/output_dir/read_level_edits_ct/*edits_*.bed'))):
            if os.path.getsize(p) != 0:
                edit_df = pd.read_csv(p, sep='\t', header=None)
                edit_df['split_label'] =  p.split('/')[-1].split('_read_level_edits')[0]
                edit_df['key'] = edit_df.apply(lambda x: f'{x[0]}:{str(x[1])}:{str(x[2])}', axis=1)
                edit_df['location'] = p.split('/')[-1].split('.bed')[0].split('edits_')[-1]
                edit_df = edit_df[edit_df['location']=='CDS'] #### ONLY KEEPING CDS
                read_level_edits_df = pd.concat([read_level_edits_df, edit_df])
            else:
                empty_splits.append(p.split('/')[-1])
        
        print(' '.join(empty_splits))
        concat_edits[key] = read_level_edits_df
        
    return concat_edits

# %%
concat_edits_wt = concat_splits_all_edits(sample_dict_wt)
# Out:
# rep1
# 100%|██████████| 777/777 [00:57<00:00, 13.47it/s]
# split_bam_21_0_read_level_edits_3utr.bed split_bam_16_0_read_level_edits_5utr.bed split_bam_19_0_read_level_edits_5utr.bed split_bam_20_0_read_level_edits_3utr.bed split_bam_20_0_read_level_edits_5utr.bed split_bam_20_0_read_level_edits_CDS.bed split_bam_21_0_read_level_edits_5utr.bed split_bam_17_0_read_level_edits_5utr.bed split_bam_21_0_read_level_edits_CDS.bed
# rep2
# 100%|██████████| 777/777 [00:42<00:00, 18.28it/s]
# split_bam_2_40_read_level_edits_5utr.bed split_bam_17_0_read_level_edits_5utr.bed

# %%
for rep in ['rep1', 'rep2']:
    print(rep)
    print(concat_edits_wt[rep]['location'].value_counts())
# Out:
# rep1
# location
# CDS    568292
# Name: count, dtype: int64
# rep2
# location
# CDS    570443
# Name: count, dtype: int64

# %%
concat_edits_cocl2 = concat_splits_all_edits(sample_dict_cocl2)
# Out:
# rep1
# 100%|██████████| 759/759 [00:45<00:00, 16.58it/s]
# split_bam_21_0_read_level_edits_3utr.bed split_bam_19_0_read_level_edits_5utr.bed split_bam_22_0_read_level_edits_3utr.bed split_bam_22_0_read_level_edits_5utr.bed split_bam_22_0_read_level_edits_CDS.bed split_bam_21_0_read_level_edits_5utr.bed split_bam_18_0_read_level_edits_5utr.bed split_bam_21_0_read_level_edits_CDS.bed
# rep2
# 100%|██████████| 744/744 [00:42<00:00, 17.71it/s]
# split_bam_21_0_read_level_edits_3utr.bed split_bam_16_0_read_level_edits_CDS.bed split_bam_16_0_read_level_edits_5utr.bed split_bam_19_0_read_level_edits_5utr.bed split_bam_15_0_read_level_edits_5utr.bed split_bam_19_0_read_level_edits_3utr.bed split_bam_22_0_read_level_edits_3utr.bed split_bam_22_0_read_level_edits_5utr.bed split_bam_22_0_read_level_edits_CDS.bed split_bam_23_0_read_level_edits_5utr.bed split_bam_21_0_read_level_edits_5utr.bed split_bam_21_0_read_level_edits_CDS.bed

# %%
for rep in ['rep1', 'rep2']:
    print(rep)
    print(concat_edits_cocl2[rep]['location'].value_counts())
# Out:
# rep1
# location
# CDS    665721
# Name: count, dtype: int64
# rep2
# location
# CDS    606272
# Name: count, dtype: int64

# %%
#concat_edits_rps2['rep1']

# %% [markdown]
# #### Get position level edits

# %%
def concat_splits_all_pos_edits(sample_dict):
    all_sample_pos_edits = {}
    for key in sample_dict:
        print(key)
        all_pos_edits_df = pd.DataFrame()
        empty_splits = []
        bed_files = [i for i in glob.glob(os.path.join(working_dir, f'{sample_dict[key]}/output_dir/*_ct_*.bed')) if '_transcript' not in i]
        for p in tqdm.tqdm(bed_files):
            if '_transcript' not in p:
                if os.path.getsize(p) != 0:
                    split_pos_edit_df = pd.read_csv(p, sep='\t', header=None)
                    split_pos_edit_df['split_label'] =  p.split('/')[-1].split('_ct_')[0]
                    split_pos_edit_df['key'] = split_pos_edit_df.apply(lambda x: f'{x[0]}:{str(x[1])}:{str(x[2])}', axis=1)
                    split_pos_edit_df['location'] = p.split('/')[-1].split('.bed')[0].split('_ct_')[-1]
                    split_pos_edit_df['conversion'] = split_pos_edit_df.apply(lambda x: int(x[4].split(',')[0]), axis=1)
                    split_pos_edit_df['coverage'] = split_pos_edit_df.apply(lambda x: int(x[4].split(',')[1]), axis=1)
                    split_pos_edit_df['edit_fraction'] = split_pos_edit_df.apply(lambda x: x['conversion']/x['coverage'], axis=1)
                    split_pos_edit_df = split_pos_edit_df[split_pos_edit_df['location']=='CDS']#### ONLY KEEPING CDS EDITS
                    all_pos_edits_df = pd.concat([all_pos_edits_df, split_pos_edit_df])
                else:
                    empty_splits.append(p.split('/')[-1])

        print(' '.join(empty_splits))
        all_sample_pos_edits[key] = all_pos_edits_df
        
    return all_sample_pos_edits

# %%
all_pos_edits_wt = concat_splits_all_pos_edits(sample_dict_wt)
# Out:
# rep1
# 100%|██████████| 777/777 [00:36<00:00, 21.51it/s]
# split_bam_19_0_ct_5utr.bed split_bam_20_0_ct_5utr.bed split_bam_21_0_ct_5utr.bed split_bam_21_0_ct_3utr.bed split_bam_16_0_ct_5utr.bed split_bam_20_0_ct_3utr.bed split_bam_21_0_ct_CDS.bed split_bam_20_0_ct_CDS.bed split_bam_17_0_ct_5utr.bed
# rep2
# 100%|██████████| 777/777 [00:35<00:00, 21.96it/s]
# split_bam_2_40_ct_5utr.bed split_bam_17_0_ct_5utr.bed

# %%
all_pos_edits_cocl2 = concat_splits_all_pos_edits(sample_dict_cocl2)
# Out:
# rep1
# 100%|██████████| 753/753 [00:32<00:00, 22.98it/s]
# split_bam_19_0_ct_5utr.bed split_bam_18_0_ct_5utr.bed
# rep2
# 100%|██████████| 743/743 [00:30<00:00, 24.65it/s]
# split_bam_19_0_ct_5utr.bed split_bam_15_0_ct_5utr.bed split_bam_22_0_ct_CDS.bed split_bam_16_0_ct_CDS.bed split_bam_22_0_ct_5utr.bed split_bam_22_0_ct_3utr.bed split_bam_21_0_ct_5utr.bed split_bam_21_0_ct_3utr.bed split_bam_23_0_ct_5utr.bed split_bam_21_0_ct_CDS.bed split_bam_19_0_ct_3utr.bed

# %%
#all_pos_edits_apo['rep1'].to_csv('APO_rep1_all_edits.tsv', sep='\t', index=False)

# %%
#all_pos_edits_rps2['rep1'].to_csv('RPS2_rep1_all_edits.tsv', sep='\t', index=False)

# %%
common_wt_sites = set(all_pos_edits_wt['rep1']['key'].tolist()).intersection(set(all_pos_edits_wt['rep2']['key'].tolist()))

# %%
common_cocl2_sites = set(all_pos_edits_cocl2['rep1']['key'].tolist()).intersection(set(all_pos_edits_cocl2['rep2']['key'].tolist()))

# %%
common_wt_cocl2_sites = common_wt_sites.intersection(common_cocl2_sites)

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.set_style('white')

for rep in ['rep1', 'rep2']:
    sns.scatterplot(data=all_pos_edits_cocl2[rep], x='edit_fraction', y='coverage', alpha=0.3, linewidth=0, color='#FE9920')
    sns.scatterplot(data=all_pos_edits_wt[rep], x='edit_fraction', y='coverage', alpha=0.3, linewidth=0, color='#028090')
    
    plt.yscale('log')
    plt.legend(['COCL2', 'WT'])
    plt.axhline(y=20, color='lightgrey', linestyle='dashed')
    # plt.savefig(os.path.join(fig_path,'sup3/edits_nofilter.png'))
    # plt.savefig(os.path.join(fig_path,'sup3/edits_nofilter.svg'))
    # plt.savefig(os.path.join(fig_path,'sup3/edits_nofilter.jpg'))
plt.show()

# %%
for rep in ['rep1', 'rep2']:
    sns.scatterplot(data=all_pos_edits_cocl2[rep][all_pos_edits_cocl2[rep]['key'].isin(common_wt_cocl2_sites)], x='edit_fraction', y='coverage', alpha=0.3, linewidth=0, color='steelblue')
    sns.scatterplot(data=all_pos_edits_wt[rep][all_pos_edits_wt[rep]['key'].isin(common_wt_cocl2_sites)], x='edit_fraction', y='coverage', alpha=0.3, linewidth=0, color='grey')
    
    plt.yscale('log')
    plt.legend(['COCL2', 'WT'])
    plt.axhline(y=20, color='lightgrey', linestyle='dashed')
plt.show()

for rep in ['rep1', 'rep2']:
    sns.scatterplot(data=all_pos_edits_cocl2[rep][~all_pos_edits_cocl2[rep]['key'].isin(common_wt_cocl2_sites)], x='edit_fraction', y='coverage', alpha=0.3, linewidth=0, color='#FE9920')
    sns.scatterplot(data=all_pos_edits_wt[rep][~all_pos_edits_wt[rep]['key'].isin(common_wt_cocl2_sites)], x='edit_fraction', y='coverage', alpha=0.3, linewidth=0, color='#028090')
    
    plt.yscale('log')
    plt.legend(['COCL2', 'WT'])
    plt.axhline(y=20, color='lightgrey', linestyle='dashed')
    # plt.savefig(os.path.join(fig_path,'sup3/edits_filter_common_sites.png'))
    # plt.savefig(os.path.join(fig_path,'sup3/edits_filter_common_sites.svg'))
    # plt.savefig(os.path.join(fig_path,'sup3/edits_filter_common_sites.jpg'))
plt.show()

# %%
all_pos_edits_wt_common_removed = {}
all_pos_edits_cocl2_common_removed = {}
for rep in ['rep1', 'rep2']:
    all_pos_edits_wt_common_removed[rep] = all_pos_edits_wt[rep][~all_pos_edits_wt[rep]['key'].isin(common_wt_cocl2_sites)]
    all_pos_edits_cocl2_common_removed[rep] = all_pos_edits_cocl2[rep][~all_pos_edits_cocl2[rep]['key'].isin(common_wt_cocl2_sites)]

# %%
# for rep in ['rep1', 'rep2', 'rep3']:
#     sns.scatterplot(data=all_pos_edits_rps2_common_removed[rep][all_pos_edits_rps2_common_removed[rep]['key'].isin(common_rps2_sites)], x='edit_fraction', y='coverage', alpha=0.3, linewidth=0, color='steelblue')
#     sns.scatterplot(data=all_pos_edits_apo_common_removed[rep][all_pos_edits_apo_common_removed[rep]['key'].isin(common_rps2_sites)], x='edit_fraction', y='coverage', alpha=0.3, linewidth=0, color='grey')
    
#     plt.yscale('log')
#     plt.legend(['RPS2', 'APOBEC1'])
#     plt.axhline(y=20, color='lightgrey', linestyle='dashed')
# plt.show()

# for rep in ['rep1', 'rep2', 'rep3']:
#     sns.scatterplot(data=all_pos_edits_rps2_common_removed[rep][~all_pos_edits_rps2_common_removed[rep]['key'].isin(common_rps2_sites)], x='edit_fraction', y='coverage', alpha=0.3, linewidth=0, color='steelblue')
#     sns.scatterplot(data=all_pos_edits_apo_common_removed[rep][~all_pos_edits_apo_common_removed[rep]['key'].isin(common_rps2_sites)], x='edit_fraction', y='coverage', alpha=0.3, linewidth=0, color='grey')
    
#     plt.yscale('log')
#     plt.legend(['RPS2', 'APOBEC1'])
#     plt.axhline(y=20, color='lightgrey', linestyle='dashed')
# plt.show()

# %%
all_pos_edits_wt_common_all_cocl2_removed = {}
all_pos_edits_cocl2_common_all_cocl2_removed = {}
for rep in ['rep1', 'rep2']:
    #all_pos_edits_apo_common_all_rps2_removed[rep] = all_pos_edits_apo_common_removed[rep][~all_pos_edits_apo_common_removed[rep]['key'].isin(common_rps2_sites)]
    #all_pos_edits_rps2_common_all_rps2_removed[rep] = all_pos_edits_rps2_common_removed[rep][~all_pos_edits_rps2_common_removed[rep]['key'].isin(common_rps2_sites)]
    all_pos_edits_wt_common_all_cocl2_removed[rep] = all_pos_edits_wt_common_removed[rep].copy()
    all_pos_edits_cocl2_common_all_cocl2_removed[rep] = all_pos_edits_cocl2_common_removed[rep].copy()

# %%
# the coordinates are 0-based, and match the edits. checked using IGV
snps = pd.read_csv('/tscc/nfs/home/pjaganna1/projects/STAMP/stamp_v3_pipeline/refs/hg38/b151_GRCh38p7_common.with_chr.bed3', sep='\t', header=None)

# %%
snps['key'] = snps.apply(lambda x: f'{x[0]}:{str(x[1])}:{str(x[2])}', axis=1)
snps['length'] = snps[2] - snps[1]
snps_list = snps['key'].tolist()

# %%
snps.head()
# Out:
#       0      1      2               key  length
# 0  chr1  10176  10177  chr1:10176:10177       1
# 1  chr1  10351  10352  chr1:10351:10352       1
# 2  chr1  10615  10616  chr1:10615:10616       1
# 3  chr1  11011  11012  chr1:11011:11012       1
# 4  chr1  11062  11063  chr1:11062:11063       1

# %%
for rep in ['rep1', 'rep2']:
    sns.scatterplot(data=all_pos_edits_cocl2_common_all_cocl2_removed[rep][all_pos_edits_cocl2_common_all_cocl2_removed[rep]['key'].isin(snps_list)], x='edit_fraction', y='coverage', alpha=0.3, linewidth=0, color='steelblue')
    sns.scatterplot(data=all_pos_edits_wt_common_all_cocl2_removed[rep][all_pos_edits_wt_common_all_cocl2_removed[rep]['key'].isin(snps_list)], x='edit_fraction', y='coverage', alpha=0.3, linewidth=0, color='grey')
    
    plt.yscale('log')
    plt.legend(['COCL2', 'WT'])
    plt.axhline(y=20, color='lightgrey', linestyle='dashed')
plt.show()

for rep in ['rep1', 'rep2']:
    sns.scatterplot(data=all_pos_edits_cocl2_common_all_cocl2_removed[rep][~all_pos_edits_cocl2_common_all_cocl2_removed[rep]['key'].isin(snps_list)], x='edit_fraction', y='coverage', alpha=0.3, linewidth=0, color='#FE9920')
    sns.scatterplot(data=all_pos_edits_wt_common_all_cocl2_removed[rep][~all_pos_edits_wt_common_all_cocl2_removed[rep]['key'].isin(snps_list)], x='edit_fraction', y='coverage', alpha=0.3, linewidth=0, color='#028090')
    
    plt.yscale('log')
    plt.legend(['COCL2', 'WT'])
    plt.axhline(y=20, color='lightgrey', linestyle='dashed')
    # plt.savefig(os.path.join(fig_path,'sup3/edits_filter_snps.png'))
    # plt.savefig(os.path.join(fig_path,'sup3/edits_filter_snps.svg'))
    # plt.savefig(os.path.join(fig_path,'sup3/edits_filter_snps.jpg'))
plt.show()

# %%
all_pos_edits_wt_common_all_cocl2_snp_removed = {}
all_pos_edits_cocl2_common_all_cocl2_snp_removed = {}
for rep in ['rep1', 'rep2']:
    all_pos_edits_wt_common_all_cocl2_snp_removed[rep] = all_pos_edits_wt_common_all_cocl2_removed[rep][~all_pos_edits_wt_common_all_cocl2_removed[rep]['key'].isin(snps_list)]
    all_pos_edits_cocl2_common_all_cocl2_snp_removed[rep] = all_pos_edits_cocl2_common_all_cocl2_removed[rep][~all_pos_edits_cocl2_common_all_cocl2_removed[rep]['key'].isin(snps_list)]

# %%
for rep in ['rep1', 'rep2']:
    read_edits_counts_wt = concat_edits_wt[rep][concat_edits_wt[rep]['key'].isin(all_pos_edits_wt_common_all_cocl2_snp_removed[rep]['key'].tolist())][3].value_counts()
    sns.displot(data=read_edits_counts_wt, height=3)
    plt.title(rep)
    plt.show()

# %%
for rep in ['rep1', 'rep2']:
    read_edits_counts_cocl2 = concat_edits_cocl2[rep][concat_edits_cocl2[rep]['key'].isin(all_pos_edits_cocl2_common_all_cocl2_snp_removed[rep]['key'].tolist())][3].value_counts()
    sns.displot(read_edits_counts_cocl2, height=3)
    plt.title(rep)
    plt.show()

# %%
for key in all_pos_edits_cocl2:
    print(key, all_pos_edits_cocl2[key].shape[0],all_pos_edits_cocl2_common_removed[key].shape[0], all_pos_edits_cocl2_common_all_cocl2_removed[key].shape[0], all_pos_edits_cocl2_common_all_cocl2_snp_removed[key].shape[0])
# Out:
# rep1 183799 131555 131555 129742
# rep2 173127 121270 121270 119549

# %%
for key in all_pos_edits_wt:
    print(key, all_pos_edits_wt[key].shape[0],all_pos_edits_wt_common_removed[key].shape[0], all_pos_edits_wt_common_all_cocl2_removed[key].shape[0], all_pos_edits_wt_common_all_cocl2_snp_removed[key].shape[0])
# Out:
# rep1 191746 140598 140598 138525
# rep2 179607 128431 128431 126527

# %%
#all_pos_edits_apo_common_all_rps2_snp_removed['rep1'][[0,1,2,3,'key', 5]].to_csv(os.path.join('/home/pjaganna1/projects/bin/metaPlotR/script_pipeline/test_script', 'apo_test.bed'), sep='\t', header=None, index=False)
#all_pos_edits_rps2_common_all_rps2_snp_removed['rep1'][[0,1,2,3,'key', 5]].to_csv(os.path.join('/home/pjaganna1/projects/bin/metaPlotR/script_pipeline/test_script', 'rps2_test.bed'), sep='\t', header=None, index=False)

# %%
print('---WT---')
for rep in ['rep1', 'rep2']:
    print(all_pos_edits_wt_common_all_cocl2_snp_removed[rep]['location'].value_counts())

print('---COCL2---')
for rep in ['rep1', 'rep2']:
    print(all_pos_edits_cocl2_common_all_cocl2_snp_removed[rep]['location'].value_counts())
# Out:
# ---WT---
# location
# CDS    138525
# Name: count, dtype: int64
# location
# CDS    126527
# Name: count, dtype: int64
# ---COCL2---
# location
# CDS    129742
# Name: count, dtype: int64
# location
# CDS    119549
# Name: count, dtype: int64

# %%
# for rep in ['rep1', 'rep2', 'rep3']:
#     all_pos_edits_apo_common_all_rps2_snp_removed[rep][[0,1,2,3,4,5]].to_csv(os.path.join(output_dir, f'APO_pos_edits_iso_{rep}_commonsites_snp_filtered.bed'), sep='\t', header=None, index=False)

# %%
# for rep in ['rep1', 'rep2', 'rep3']:
#     all_pos_edits_rps2_common_all_rps2_snp_removed[rep][[0,1,2,3,4,5]].to_csv(os.path.join(output_dir, f'RPS2_pos_edits_iso_{rep}_commonsites_snp_filtered.bed'), sep='\t', header=None, index=False)

# %%
coverage_filtered_cocl2 = {}
coverage_filtered_wt = {}
for rep in ['rep1', 'rep2']:
    coverage_filtered_cocl2[rep] = all_pos_edits_cocl2_common_all_cocl2_snp_removed[rep][all_pos_edits_cocl2_common_all_cocl2_snp_removed[rep]['coverage'] >=20]
    coverage_filtered_wt[rep] = all_pos_edits_wt_common_all_cocl2_snp_removed[rep][all_pos_edits_wt_common_all_cocl2_snp_removed[rep]['coverage']>=20]

# %%
# for rep in ['rep1', 'rep2', 'rep3']:
#     coverage_filtered_apo[rep][[0,1,2,3,4,5]].to_csv(os.path.join(output_dir, f'APO_pos_edits_iso_{rep}_commonsites_snp_cov_filtered.bed'), sep='\t', header=None, index=False)

# %%
# for rep in ['rep1', 'rep2', 'rep3']:
#     coverage_filtered_rps2[rep][[0,1,2,3,4,5]].to_csv(os.path.join(output_dir, f'RPS2_pos_edits_iso_{rep}_commonsites_snp_cov_filtered.bed'), sep='\t', header=None, index=False)

# %%
keep_edits_wt = {}
for rep in ['rep1', 'rep2']:
    df_wt = all_pos_edits_wt_common_all_cocl2_snp_removed[rep].copy()
    df_wt['gene_id'] = df_wt.apply(lambda x: x[3].split(':')[0], axis=1)
    df_wt['transcript_id'] = df_wt.apply(lambda x: x[3].split(':')[1], axis=1)
    #df_apo = df_apo[df_apo['coverage']>=20]
    keep_edits_wt[rep] = df_wt

# %%
keep_edits_cocl2 = {}
for rep in ['rep1', 'rep2']:
    df_cocl2 = all_pos_edits_cocl2_common_all_cocl2_snp_removed[rep].copy()
    df_cocl2['gene_id'] = df_cocl2.apply(lambda x: x[3].split(':')[0], axis=1)
    df_cocl2['transcript_id'] = df_cocl2.apply(lambda x: x[3].split(':')[1], axis=1)
    #df_rps2 = df_rps2[df_rps2['coverage']>=20]
    keep_edits_cocl2[rep] = df_cocl2

# %%
for r in ['rep1', 'rep2']:
    keep_edits_wt[r][[0,1,2,3,4,5]].to_csv(os.path.join('/tscc/nfs/home/pjaganna1/projects/STAMP/LR-Ribo-STAMP_GEO_2024/processed_files', f'Ribo-STAMP_MDA-MB-231_NT_{r}_CDS_edits.bed'), sep='\t', header=None, index=False)
    keep_edits_cocl2[r][[0,1,2,3,4,5]].to_csv(os.path.join('/tscc/nfs/home/pjaganna1/projects/STAMP/LR-Ribo-STAMP_GEO_2024/processed_files', f'Ribo-STAMP_MDA-MB-231_CoCl2_{r}_CDS_edits.bed'), sep='\t', header=None, index=False)

# %%
mapped_edits = []
for sample_dict in [['NT', sample_dict_wt], ['COCL2',sample_dict_cocl2]]:
    s = sample_dict[0]
    d = sample_dict[1]
    for r in ['rep1', 'rep2']:
        if s=='NT':
            mapped_edits.append([d[r], total_mapped_reads[d[r]], 'mapped reads'])
            mapped_edits.append([d[r], keep_edits_wt[r].shape[0], 'edits'])
        elif s=='COCL2':
            mapped_edits.append([d[r], total_mapped_reads[d[r]], 'mapped reads'])
            mapped_edits.append([d[r], keep_edits_cocl2[r].shape[0], 'edits'])

# %%
mapped_edits_df = pd.DataFrame(mapped_edits, columns=['sample', 'counts', 'metric'])

# %%
mapped_edits_df
# Out:
#            sample   counts        metric
# 0     231_NT_rep1  1780998  mapped reads
# 1     231_NT_rep1   138525         edits
# 2     231_NT_rep2  1793845  mapped reads
# 3     231_NT_rep2   126527         edits
# 4  231_cocl2_rep1  1839690  mapped reads
# 5  231_cocl2_rep1   129742         edits
# 6  231_cocl2_rep2  1711925  mapped reads
# 7  231_cocl2_rep2   119549         edits

# %%
sns.barplot(data=mapped_edits_df, x='sample', y='counts', hue='metric', palette=custom_palette[2:])
plt.yscale('log')
plt.legend([])
# plt.savefig(os.path.join(fig_path,'sup3/mapped_reads_edits.png'))
# plt.savefig(os.path.join(fig_path,'sup3/mapped_reads_edits.svg'))
# plt.savefig(os.path.join(fig_path,'sup3/mapped_reads_edits.jpg'))
# Out:
# /tmp/ipykernel_3989180/1411954002.py:1: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.barplot(data=mapped_edits_df, x='sample', y='counts', hue='metric', palette=custom_palette[2:])

# %% [markdown]
# ### Getting Exon and UTRs gene and Transcript (Don't need to re-run unless creating files again')

# %%
def gtf_to_bed(gtf_file, bed_file):
    # Read the GTF file
    # GTF columns: chromosome, source, feature, start, end, score, strand, frame, attribute
    gtf_df = pd.read_csv(gtf_file, sep='\t', comment='#', header=None,
                     names=['chrom', 'source', 'feature', 'start', 'end', 'score', 'strand', 'frame', 'attribute'])
    # Filter for exons and UTRs
    gtf_df = gtf_df[gtf_df['feature'].isin(['exon', 'UTR'])]

    # Extract gene name from the attribute field
    gtf_df['gene_name'] = gtf_df['attribute'].str.extract('gene_id "([^"]+)"')

    # Create a BED formatted DataFrame
    bed_df = gtf_df[['chrom', 'start', 'end', 'gene_name', 'score', 'strand']]

    # Adjust start position for BED format (0-based start, GTF is 1-based)
    bed_df['start'] = bed_df['start'] - 1

    # Write to BED file
    bed_df.to_csv(bed_file, sep='\t', index=False, header=False)

# %%
gtf_file = '/tscc/nfs/home/pjaganna1/projects/STAMP/stamp_v3_pipeline/refs/hg38/gencode.v38.annotation.gtf'  # Replace with your GTF file path
bed_file = '/tscc/nfs/home/pjaganna1/projects/STAMP/stamp_v3_pipeline/refs/hg38/output_exons_utrs.genes.bed'
#gtf_to_bed(gtf_file, bed_file)

# %% [markdown]
# ```sort -k1,1 -k2,2n output_exons_utrs.bed > output_exons_utrs.sorted.bed```

# %% [markdown]
# ```bedtools merge -i output_exons_utrs.genes.sorted.bed -s -c 4,6 -o distinct > merged_exons_utrs.genes.hg19.bed```

# %% [markdown]
# ```bedtools getfasta -fi hg19.fa -bed merged_exons_utrs.genes.hg19.bed -name -s > merged_exons_utrs.genes.hg19.fasta```

# %%
def count_cytosines(fasta_file):
    cytosine_counts = {}
    for record in SeqIO.parse(fasta_file, "fasta"):
        gene_ids = record.id.split("(")[0].split(',')  # Had to change this for hg38. In hg19 was splitting based on ':'
        sequence = str(record.seq).upper()
        for gene_id in gene_ids:
            if gene_id in cytosine_counts:
                cytosine_counts[gene_id] += sequence.count('C')
            else:
                cytosine_counts[gene_id] = sequence.count('C')
    return cytosine_counts

# %%
gene_coordinates_fasta = '/tscc/nfs/home/pjaganna1/projects/STAMP/stamp_v3_pipeline/refs/hg38/merged_exons_utrs.genes.hg38.fasta'

# %%
gene_cytosine_counts = count_cytosines(gene_coordinates_fasta)

# %%
list(gene_cytosine_counts.keys())[:5]
# Out:
# ['ENSG00000223972.5',
#  'ENSG00000227232.5',
#  'ENSG00000278267.1',
#  'ENSG00000243485.5',
#  'ENSG00000284332.1']

# %%
def gtf_to_bed_transcript(gtf_file, bed_file):
    # Read the GTF file
    # GTF columns: chromosome, source, feature, start, end, score, strand, frame, attribute
    gtf_df = pd.read_csv(gtf_file, sep='\t', comment='#', header=None,
                     names=['chrom', 'source', 'feature', 'start', 'end', 'score', 'strand', 'frame', 'attribute'])
    # Filter for exons and UTRs
    gtf_df = gtf_df[gtf_df['feature'].isin(['exon', 'UTR'])]

    # Extract gene name from the attribute field
    gtf_df['transcript_id'] = gtf_df['attribute'].str.extract('transcript_id "([^"]+)"')

    # Create a BED formatted DataFrame
    bed_df = gtf_df[['chrom', 'start', 'end', 'transcript_id', 'score', 'strand']]

    # Adjust start position for BED format (0-based start, GTF is 1-based)
    bed_df['start'] = bed_df['start'] - 1

    # Write to BED file
    bed_df.to_csv(bed_file, sep='\t', index=False, header=False)

# %%
transcript_bed_file = '/tscc/nfs/home/pjaganna1/projects/STAMP/stamp_v3_pipeline/refs/hg38/output_exons_utrs.transcript.bed'
#gtf_to_bed_transcript(gtf_file, transcript_bed_file)

# %% [markdown]
# ```sort -k1,1 -k2,2n output_exons_utrs.transcript.bed > output_exons_utrs.transcript.sorted.bed```
#
# ```bedtools merge -i output_exons_utrs.transcript.sorted.bed -s -c 4,6 -o distinct > merged_exons_utrs.transcript.hg19.bed```
#
# ```bedtools getfasta -fi hg19.fa -bed merged_exons_utrs.transcript.hg19.bed -name -s > merged_exons_utrs.transcript.hg19.fasta```

# %%
def count_cytosines_transcript(fasta_file):
    cytosine_counts = {}
    for record in SeqIO.parse(fasta_file, "fasta"):
        ids = record.id.split("(")[0].split(',')  # Adjust based on your FASTA header format
        sequence = str(record.seq).upper()
        for transcript in ids:
            if transcript in cytosine_counts:
                cytosine_counts[transcript] += sequence.count('C')
            else:
                cytosine_counts[transcript] = sequence.count('C')
    return cytosine_counts

# %%
transcript_coordinates_fasta = '/tscc/nfs/home/pjaganna1/projects/STAMP/stamp_v3_pipeline/refs/hg38/merged_exons_utrs.transcript.hg38.fasta'

# %%
transcript_cytosine_counts = count_cytosines_transcript(transcript_coordinates_fasta)

# %%
def calculate_editsC(keep_edits, c_counts):
    gene_editsC = {}
    for rep in ['rep1', 'rep2']:
        edit_count_gene = keep_edits[rep].drop_duplicates(subset=[0,1,2,5, 'gene_id']).groupby('gene_id').count()[[0]]
        edit_count_gene['num_c'] = edit_count_gene.index.map(c_counts)
        edit_count_gene = edit_count_gene.rename(columns={0:'edited_c'})
        edit_count_gene['editsC'] = edit_count_gene['edited_c']/edit_count_gene['num_c']
        gene_editsC[rep] = edit_count_gene
    return gene_editsC

# %%
wt_gene_editsC = calculate_editsC(keep_edits_wt, gene_cytosine_counts)

# %%
cocl2_gene_editsC = calculate_editsC(keep_edits_cocl2, gene_cytosine_counts)

# %%
wt_gene_editsC['rep1'].head()
# Out:
#                     edited_c  num_c    editsC
# gene_id
# ENSG00000000003.15        20   1054  0.018975
# ENSG00000000419.14         8   1956  0.004090
# ENSG00000000460.17         1   1355  0.000738
# ENSG00000000971.16        20   1321  0.015140
# ENSG00000001036.14        35    648  0.054012

# %%
def calculate_editsC_transcript(keep_edits, c_counts):
    transcript_editsC = {}
    for rep in ['rep1', 'rep2']:
        edit_count_transcript = keep_edits[rep].groupby('transcript_id').count()[[0]]
        edit_count_transcript['num_c'] = edit_count_transcript.index.map(c_counts)
        edit_count_transcript = edit_count_transcript.rename(columns={0:'edited_c'})
        edit_count_transcript['editsC'] = edit_count_transcript['edited_c']/edit_count_transcript['num_c']
        transcript_editsC[rep] = edit_count_transcript
    return transcript_editsC

# %%
wt_transcript_editsC = calculate_editsC_transcript(keep_edits_wt, transcript_cytosine_counts)
cocl2_transcript_editsC = calculate_editsC_transcript(keep_edits_cocl2, transcript_cytosine_counts)

# %%
wt_transcript_editsC['rep1'].head()
# Out:
#                     edited_c  num_c    editsC
# transcript_id
# ENST00000000233.10        10    635  0.015748
# ENST00000000412.8         23    817  0.028152
# ENST00000000442.11         6    774  0.007752
# ENST00000001008.6         50    998  0.050100
# ENST00000002125.9          6    556  0.010791

# %%
# for rep in ['rep1', 'rep2']:
#     keep_edits_wt[rep].to_csv(f'NT_edits_{rep}_jan2024.txt', sep='\t', header=None, index=False)
#     keep_edits_wt[rep][[0,1,2,3,4,5]].to_csv(f'NT_edits_{rep}_jan2024.bed', sep='\t', header=None, index=False)
#     keep_edits_cocl2[rep].to_csv(f'COCL2_edits_{rep}_jan2024.txt', sep='\t', header=None, index=False)
#     keep_edits_cocl2[rep][[0,1,2,3,4,5]].to_csv(f'COCL2_edits_{rep}_jan2024.bed', sep='\t', header=None, index=False)

# %%
def make_heatmap(wt_dict, cocl2_dict):
    editsC_heatmap = pd.DataFrame()
    for sample, d in [('NT', wt_dict), ('COCL2', cocl2_dict)]:
        for rep in ['rep1', 'rep2']:
            d[rep] = d[rep].rename(columns={'editsC' : f'editsC_{sample}_{rep}'})
            editsC_heatmap = pd.concat([editsC_heatmap, d[rep][[f'editsC_{sample}_{rep}']]], axis=1)
    sns.clustermap(editsC_heatmap.dropna(), cmap='cividis')
    plt.show()
    return editsC_heatmap

# %%
gene_editsC = make_heatmap(wt_gene_editsC, cocl2_gene_editsC)
# Out:
# /tscc/projects/ps-yeolab4/software/miniconda_tscc2/envs/python3essential-1.99.0/lib/python3.9/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# /tscc/projects/ps-yeolab4/software/miniconda_tscc2/envs/python3essential-1.99.0/lib/python3.9/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
gene_editsC.dropna().head()
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# gene_id
# ENSG00000000003.15        0.018975        0.021822           0.012334
# ENSG00000000419.14        0.004090        0.008180           0.007669
# ENSG00000000971.16        0.015140        0.009084           0.003785
# ENSG00000001036.14        0.054012        0.094136           0.095679
# ENSG00000001460.18        0.001918        0.001439           0.001918
#
#                     editsC_COCL2_rep2
# gene_id
# ENSG00000000003.15           0.024668
# ENSG00000000419.14           0.006646
# ENSG00000000971.16           0.006056
# ENSG00000001036.14           0.098765
# ENSG00000001460.18           0.001439

# %%
gene_editsC.dropna().shape
# Out:
# (6242, 4)

# %%
transcript_editsC = make_heatmap(wt_transcript_editsC, cocl2_transcript_editsC)
# Out:
# /tscc/projects/ps-yeolab4/software/miniconda_tscc2/envs/python3essential-1.99.0/lib/python3.9/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# /tscc/projects/ps-yeolab4/software/miniconda_tscc2/envs/python3essential-1.99.0/lib/python3.9/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
transcript_editsC.dropna().shape
# Out:
# (7321, 4)

# %%
gene_editsC.head()
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# gene_id
# ENSG00000000003.15        0.018975        0.021822           0.012334
# ENSG00000000419.14        0.004090        0.008180           0.007669
# ENSG00000000460.17        0.000738        0.000738                NaN
# ENSG00000000971.16        0.015140        0.009084           0.003785
# ENSG00000001036.14        0.054012        0.094136           0.095679
#
#                     editsC_COCL2_rep2
# gene_id
# ENSG00000000003.15           0.024668
# ENSG00000000419.14           0.006646
# ENSG00000000460.17                NaN
# ENSG00000000971.16           0.006056
# ENSG00000001036.14           0.098765

# %%
#gene_editsC.to_csv('231_NT_COCL2_gene_editsC_Jan2024.txt', sep='\t')

# %%
#transcript_editsC.to_csv('231_NT_COCL2_transcript_editsC_Jan2024.txt', sep='\t')

# %%
def parse_gtf(gtf_file_path):
    # Read GTF file, skipping header lines starting with '#'
    df_gtf = pd.read_csv(gtf_file_path, sep='\t', comment='#', header=None, names=['seqname', 'source', 'feature', 'start', 'end', 'score', 'strand', 'frame', 'attribute'])

    # Filter for gene features
    df_gtf = df_gtf[df_gtf['feature'] == 'gene']

    # Extract gene ID, gene name, and gene type from the 'attribute' column
    df_gtf['gene_id'] = df_gtf['attribute'].str.extract('gene_id "([^"]+)"')
    df_gtf['gene_name'] = df_gtf['attribute'].str.extract('gene_name "([^"]+)"')
    df_gtf['gene_type'] = df_gtf['attribute'].str.extract('gene_type "([^"]+)"')

    # Create a new DataFrame with just the gene ID, gene name, and gene type
    df_genes = df_gtf[['gene_id', 'gene_name', 'gene_type']].set_index('gene_id')

    return df_genes

def annotate_dataframe(gene_editsC_df, gtf_file_path):
    # Parse the GTF file
    df_genes_annotations = parse_gtf(gtf_file_path)

    # Merge with the existing DataFrame
    annotated_df = gene_editsC_df.merge(df_genes_annotations, left_index=True, right_index=True, how='left')

    return annotated_df

# %%
def parse_gtf_for_transcripts(gtf_file_path):
    # Read GTF file, skipping header lines starting with '#'
    df_gtf = pd.read_csv(gtf_file_path, sep='\t', comment='#', header=None,names=['seqname', 'source', 'feature', 'start', 'end', 'score', 'strand', 'frame', 'attribute'])

    # Filter for transcript features
    df_gtf = df_gtf[df_gtf['feature'] == 'transcript']

    # Extract transcript ID, gene name, and transcript type from the 'attribute' column
    df_gtf['transcript_id'] = df_gtf['attribute'].str.extract('transcript_id "([^"]+)"')
    df_gtf['gene_name'] = df_gtf['attribute'].str.extract('gene_name "([^"]+)"')
    df_gtf['transcript_type'] = df_gtf['attribute'].str.extract('transcript_type "([^"]+)"')

    # Create a new DataFrame with just the transcript ID, gene name, and transcript type
    df_transcripts = df_gtf[['transcript_id', 'gene_name', 'transcript_type']].set_index('transcript_id')

    return df_transcripts

def annotate_dataframe_with_transcript_info(transcript_editsC_df, gtf_file_path):
    # Parse the GTF file for transcripts
    df_transcripts = parse_gtf_for_transcripts(gtf_file_path)

    # Merge with the existing DataFrame
    annotated_df = transcript_editsC_df.merge(df_transcripts, left_index=True, right_index=True, how='left')

    return annotated_df

# %%
def calculate_mean_wt(data):
    return np.mean([data['editsC_NT_rep1'], data['editsC_NT_rep2']])

def calculate_mean_cocl2(data):
    return np.mean([data['editsC_COCL2_rep1'], data['editsC_COCL2_rep2']])

# %%
annotated_gene_editsC = annotate_dataframe(gene_editsC, gtf_file)

# %%
annotated_gene_editsC['ensembl_gene_id'] = annotated_gene_editsC.apply(lambda x: x.name.split('.')[0], axis=1)

# %%
annotated_gene_editsC.dropna().head()
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# gene_id
# ENSG00000000003.15        0.018975        0.021822           0.012334
# ENSG00000000419.14        0.004090        0.008180           0.007669
# ENSG00000000971.16        0.015140        0.009084           0.003785
# ENSG00000001036.14        0.054012        0.094136           0.095679
# ENSG00000001460.18        0.001918        0.001439           0.001918
#
#                     editsC_COCL2_rep2 gene_name       gene_type  \
# gene_id
# ENSG00000000003.15           0.024668    TSPAN6  protein_coding
# ENSG00000000419.14           0.006646      DPM1  protein_coding
# ENSG00000000971.16           0.006056       CFH  protein_coding
# ENSG00000001036.14           0.098765     FUCA2  protein_coding
# ENSG00000001460.18           0.001439     STPG1  protein_coding
#
#                     ensembl_gene_id
# gene_id
# ENSG00000000003.15  ENSG00000000003
# ENSG00000000419.14  ENSG00000000419
# ...

# %%
annotated_gene_editsC['gene_type'].value_counts()
# Out:
# gene_type
# protein_coding    9764
# TR_C_gene            1
# Name: count, dtype: int64

# %%
annotated_gene_editsC.dropna().head()
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# gene_id
# ENSG00000000003.15        0.018975        0.021822           0.012334
# ENSG00000000419.14        0.004090        0.008180           0.007669
# ENSG00000000971.16        0.015140        0.009084           0.003785
# ENSG00000001036.14        0.054012        0.094136           0.095679
# ENSG00000001460.18        0.001918        0.001439           0.001918
#
#                     editsC_COCL2_rep2 gene_name       gene_type  \
# gene_id
# ENSG00000000003.15           0.024668    TSPAN6  protein_coding
# ENSG00000000419.14           0.006646      DPM1  protein_coding
# ENSG00000000971.16           0.006056       CFH  protein_coding
# ENSG00000001036.14           0.098765     FUCA2  protein_coding
# ENSG00000001460.18           0.001439     STPG1  protein_coding
#
#                     ensembl_gene_id
# gene_id
# ENSG00000000003.15  ENSG00000000003
# ENSG00000000419.14  ENSG00000000419
# ...

# %%
annotated_gene_editsC = pd.concat([annotated_gene_editsC, pd.read_csv('231_WT_vs_Cocl2_gene.csv', index_col=0)], axis=1)

# %%
annotated_gene_editsC.dropna().head()
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENSG00000000003.15        0.018975        0.021822           0.012334
# ENSG00000000419.14        0.004090        0.008180           0.007669
# ENSG00000001036.14        0.054012        0.094136           0.095679
# ENSG00000001461.17        0.001410        0.005639           0.005639
# ENSG00000001630.17        0.022280        0.024902           0.010485
#
#                     editsC_COCL2_rep2 gene_name       gene_type  \
# ENSG00000000003.15           0.024668    TSPAN6  protein_coding
# ENSG00000000419.14           0.006646      DPM1  protein_coding
# ENSG00000001036.14           0.098765     FUCA2  protein_coding
# ENSG00000001461.17           0.008459    NIPAL3  protein_coding
# ENSG00000001630.17           0.011796   CYP51A1  protein_coding
#
#                     ensembl_gene_id    baseMean  log2FoldChange     lfcSE  \
# ENSG00000000003.15  ENSG00000000003   84.179709       -0.529452  0.386774
# ...

# %%
annotated_gene_editsC.dropna()[annotated_gene_editsC.dropna()['gene_name'].str.contains('EPA')]
# Out:
# Empty DataFrame
# Columns: [editsC_NT_rep1, editsC_NT_rep2, editsC_COCL2_rep1, editsC_COCL2_rep2, gene_name, gene_type, ensembl_gene_id, baseMean, log2FoldChange, lfcSE, stat, pvalue, padj]
# Index: []

# %%
sr_data = pd.read_csv('SR_overall_genes_of_interest_with_edits_and_deseq2_info.tsv', sep='\t', index_col=0)

# %%
sr_data.columns
# Out:
# Index(['231_RPS2_1', '231_RPS2_2', '231_RPS2_3', '231_RPS2_CoCl2_1',
#        '231_RPS2_CoCl2_2', '231_RPS2_CoCl2_3', '231_RPS2_Torin_1',
#        '231_RPS2_Torin_2', '231_RPS2_Torin_3', 'statistic', 'gene_name',
#        'baseMean', 'log2FoldChange', 'stat', 'padj', 'log10adj_pval',
#        'epr_ratio', 'pvalue', 'lfcSE', 'pvalue_deseq2'],
#       dtype='object')

# %%
sr_data = sr_data[['231_RPS2_1', '231_RPS2_2', '231_RPS2_3','231_RPS2_CoCl2_1', '231_RPS2_CoCl2_2', '231_RPS2_CoCl2_3', 'statistic','gene_name', 'baseMean', 'log2FoldChange', 'stat', 'padj','log10adj_pval', 'epr_ratio', 'pvalue', 'lfcSE', 'pvalue_deseq2']]

# %%
sr_data.head()
# Out:
#           231_RPS2_1  231_RPS2_2  231_RPS2_3  231_RPS2_CoCl2_1  \
# ABCC10       0.00000    0.000000    0.000000          0.004057
# AP2A1        0.00256    0.003094    0.002633          0.004823
# ATG4B        0.00000    0.000000    0.000000          0.001613
# ATP2B1       0.00000    0.000000    0.000000          0.001665
# ATP6V0A1     0.00000    0.000000    0.000000          0.003597
#
#           231_RPS2_CoCl2_2  231_RPS2_CoCl2_3  statistic gene_name   baseMean  \
# ABCC10            0.004983          0.002315  -4.838631    ABCC10  14.108066
# AP2A1             0.006032          0.007326  -4.445490     AP2A1  23.715132
# ATG4B             0.001443          0.002083  -8.944937     ATG4B   5.942093
# ATP2B1            0.003786          0.001637  -3.319125    ATP2B1   6.257060
# ATP6V0A1          0.001558          0.002237  -4.109522  ATP6V0A1   1.864063
#
#           log2FoldChange      stat      padj  log10adj_pval  epr_ratio  \
# ...

# %%
sr_data['231_NT_mean_SR'] = sr_data.apply(lambda x: np.mean([x['231_RPS2_1'], x['231_RPS2_2'], x['231_RPS2_1']]), axis=1)
sr_data['231_COCL2_mean_SR'] = sr_data.apply(lambda x: np.mean([x['231_RPS2_CoCl2_1'], x['231_RPS2_CoCl2_2'], x['231_RPS2_CoCl2_3']]), axis=1)

# %%
sr_data.head()
# Out:
#           231_RPS2_1  231_RPS2_2  231_RPS2_3  231_RPS2_CoCl2_1  \
# ABCC10       0.00000    0.000000    0.000000          0.004057
# AP2A1        0.00256    0.003094    0.002633          0.004823
# ATG4B        0.00000    0.000000    0.000000          0.001613
# ATP2B1       0.00000    0.000000    0.000000          0.001665
# ATP6V0A1     0.00000    0.000000    0.000000          0.003597
#
#           231_RPS2_CoCl2_2  231_RPS2_CoCl2_3  statistic gene_name   baseMean  \
# ABCC10            0.004983          0.002315  -4.838631    ABCC10  14.108066
# AP2A1             0.006032          0.007326  -4.445490     AP2A1  23.715132
# ATG4B             0.001443          0.002083  -8.944937     ATG4B   5.942093
# ATP2B1            0.003786          0.001637  -3.319125    ATP2B1   6.257060
# ATP6V0A1          0.001558          0.002237  -4.109522  ATP6V0A1   1.864063
#
#           log2FoldChange      stat      padj  log10adj_pval  epr_ratio  \
# ...

# %%
# def epkm(kept_edits, total_mapped,r):
#     """
#     Just like "RPKM" except we're looking at the number of edits (edit_counts).
#     edit_counts = total number of edit conversions across a genic region (all exons, or 3'UTR+CDS, or CDS)
#     If a read contains multiple C>T conversions, we end up counting it multiple times. Perhaps that's okay?
#     """
#     gene_epkm_edit_count = kept_edits.drop_duplicates(subset=[0,1,2,5, 'gene_id']).groupby('gene_id').count()[[0]].reset_index()
#     gene_epkm_edit_count = gene_epkm_edit_count.rename(columns={0:f'edit_count_{r}'})
#     gene_epkm_edit_count['length'] = gene_epkm_edit_count.gene_id.map(gene_length_dict)
#     gene_epkm_edit_count[f'epkm_{r}'] =  gene_epkm_edit_count.apply(lambda x: x[f'edit_count_{r}']/((total_mapped/1000000.)*(x['length']/1000.)), axis=1)
#     return gene_epkm_edit_count

# %%
# def calculate_mean_epkm_apo(data):
#     return np.mean([data['epkm_rep1_apo'], data['epkm_rep2_apo'], data['epkm_rep3_apo']])

# def calculate_mean_epkm_rps2(data):
#     return np.mean([data['epkm_rep1_rps2'], data['epkm_rep2_rps2'], data['epkm_rep3_rps2']])

# %%
# rps2_epkm = {}
# apo_epkm = {}
# for rep in ['rep1', 'rep2', 'rep3']:
#     apo_epkm[rep] = epkm(keep_edits_apo[rep], total_mapped_reads[sample_dict_apo[rep]], rep)
#     rps2_epkm[rep] = epkm(keep_edits_rps2[rep], total_mapped_reads[sample_dict_rps2[rep]], rep)

# %%
# rps2_epkm_all = pd.concat([rps2_epkm['rep1'].set_index('gene_id'), rps2_epkm['rep2'].set_index('gene_id'), rps2_epkm['rep3'].set_index('gene_id')], axis=1)[['edit_count_rep1', 'edit_count_rep2', 'edit_count_rep3', 'epkm_rep1', 'epkm_rep2', 'epkm_rep3']]

# %%
# rps2_epkm_all.head()

# %%
# apo_epkm_all = pd.concat([apo_epkm['rep1'].set_index('gene_id'), apo_epkm['rep2'].set_index('gene_id'), apo_epkm['rep3'].set_index('gene_id')], axis=1)[['edit_count_rep1', 'edit_count_rep2', 'edit_count_rep3', 'epkm_rep1', 'epkm_rep2', 'epkm_rep3']]

# %%
# gene_epkm = apo_epkm_all.merge(rps2_epkm_all, left_index=True, right_index=True, suffixes=['_apo', '_rps2'])

# %%
# annotated_gene_epkm = annotate_dataframe(gene_epkm, gtf_file)

# %%
# annotated_gene_epkm.dropna().head()

# %%
annotated_gene_editsC_copy = annotated_gene_editsC.copy()
# annotated_gene_epkm_copy = annotated_gene_epkm.copy()

# %%
for key in gene_counts:
    annotated_gene_editsC_copy = pd.concat([annotated_gene_editsC_copy, gene_counts[key].set_index('Geneid')], axis=1)
    #annotated_gene_epkm_copy = pd.concat([annotated_gene_epkm_copy, feature_counts[key].set_index('Geneid')], axis=1)

# %%
annotated_gene_editsC_copy.head()
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENSG00000000003.15        0.018975        0.021822           0.012334
# ENSG00000000419.14        0.004090        0.008180           0.007669
# ENSG00000000460.17        0.000738        0.000738                NaN
# ENSG00000000971.16        0.015140        0.009084           0.003785
# ENSG00000001036.14        0.054012        0.094136           0.095679
#
#                     editsC_COCL2_rep2 gene_name       gene_type  \
# ENSG00000000003.15           0.024668    TSPAN6  protein_coding
# ENSG00000000419.14           0.006646      DPM1  protein_coding
# ENSG00000000460.17                NaN  C1orf112  protein_coding
# ENSG00000000971.16           0.006056       CFH  protein_coding
# ENSG00000001036.14           0.098765     FUCA2  protein_coding
#
#                     ensembl_gene_id    baseMean  log2FoldChange     lfcSE  \
# ENSG00000000003.15  ENSG00000000003   84.179709       -0.529452  0.386774
# ...

# %%
annotated_gene_editsC_copy.columns
# Out:
# Index(['editsC_NT_rep1', 'editsC_NT_rep2', 'editsC_COCL2_rep1',
#        'editsC_COCL2_rep2', 'gene_name', 'gene_type', 'ensembl_gene_id',
#        'baseMean', 'log2FoldChange', 'lfcSE', 'stat', 'pvalue', 'padj',
#        '231_NT_rep1', 'Length', '231_NT_rep1_RPKM', '231_cocl2_rep1', 'Length',
#        '231_cocl2_rep1_RPKM', '231_NT_rep2', 'Length', '231_NT_rep2_RPKM',
#        '231_cocl2_rep2', 'Length', '231_cocl2_rep2_RPKM'],
#       dtype='object')

# %%
def add_zero_edits(df, metric):
    if metric =='editsC':
        for rep in ['1', '2']:
            df.loc[~df[f'231_NT_rep{rep}'].isna() & df[f'editsC_NT_rep{rep}'].isna(), f'editsC_NT_rep{rep}'] = 0
            df.loc[~df[f'231_cocl2_rep{rep}'].isna()& df[f'editsC_COCL2_rep{rep}'].isna(), f'editsC_COCL2_rep{rep}'] = 0
    # elif metric=='epkm':
    #     for rep in ['1', '2', '3']:
    #         df.loc[~df[f'APO1_{rep}'].isna() & df[f'epkm_rep{rep}_apo'].isna(), f'epkm_rep{rep}_apo'] = 0
    #         df.loc[~df[f'RPS2_{rep}'].isna()& df[f'epkm_rep{rep}_rps2'].isna(), f'epkm_rep{rep}_rps2'] = 0  
        
    return df

# %%
annotated_gene_editsC_copy=add_zero_edits(annotated_gene_editsC_copy, 'editsC')

# %%
annotated_gene_editsC_copy[annotated_gene_editsC_copy['gene_name']=='HIF1A']
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENSG00000100644.17        0.082067        0.045593           0.033435
#
#                     editsC_COCL2_rep2 gene_name       gene_type  \
# ENSG00000100644.17           0.038501     HIF1A  protein_coding
#
#                     ensembl_gene_id    baseMean  log2FoldChange     lfcSE  \
# ENSG00000100644.17  ENSG00000100644  134.568873       -1.286195  0.358268
#
#                     ...  231_NT_rep1_RPKM  231_cocl2_rep1   Length  \
# ENSG00000100644.17  ...          3.739373            62.0  52747.0
#
#                     231_cocl2_rep1_RPKM  231_NT_rep2   Length  \
# ENSG00000100644.17             0.960091        155.0  52747.0
#
#                     231_NT_rep2_RPKM  231_cocl2_rep2   Length  \
# ENSG00000100644.17          2.527714            90.0  52747.0
#
#                     231_cocl2_rep2_RPKM
# ENSG00000100644.17             1.505213
#
# [1 rows x 25 columns]

# %%
from scipy import stats

# %%
annotated_gene_editsC_copy['NT_mean'] = annotated_gene_editsC_copy.apply(calculate_mean_wt, axis=1)
annotated_gene_editsC_copy['COCL2_mean'] = annotated_gene_editsC_copy.apply(calculate_mean_cocl2, axis=1)

# %%
sns.scatterplot(data=annotated_gene_editsC_copy, x='editsC_NT_rep1', y='editsC_NT_rep2', linewidth=0, alpha=0.5, color=custom_palette[5])
plt.title('EditsC NT Correlation')
print(stats.pearsonr(annotated_gene_editsC_copy.dropna()['editsC_NT_rep1'], annotated_gene_editsC_copy.dropna()['editsC_NT_rep2']))
plt.text(0.25, 0.2, stats.pearsonr(annotated_gene_editsC_copy.dropna()['editsC_NT_rep1'], annotated_gene_editsC_copy.dropna()['editsC_NT_rep2'])[0])
# plt.savefig(os.path.join(fig_path,'sup3/gene_rep_NT_corr.png'))
# plt.savefig(os.path.join(fig_path,'sup3/gene_rep_NT_corr.svg'))
# plt.savefig(os.path.join(fig_path,'sup3/gene_rep_NT_corr.jpg'))
# Out:
# PearsonRResult(statistic=0.8717270887305016, pvalue=0.0)
# Text(0.25, 0.2, '0.8717270887305016')

# %%
sns.scatterplot(data=annotated_gene_editsC_copy, x='editsC_COCL2_rep1', y='editsC_COCL2_rep2', linewidth=0, alpha=0.5, color=custom_palette[5])
plt.title('EditsC COCL2 Correlation')
print(stats.pearsonr(annotated_gene_editsC_copy.dropna()['editsC_COCL2_rep1'], annotated_gene_editsC_copy.dropna()['editsC_COCL2_rep2']))
plt.text(0.25, 0.2, stats.pearsonr(annotated_gene_editsC_copy.dropna()['editsC_COCL2_rep1'], annotated_gene_editsC_copy.dropna()['editsC_COCL2_rep2'])[0])

# plt.savefig(os.path.join(fig_path,'sup3/gene_rep_COCL2_corr.png'))
# plt.savefig(os.path.join(fig_path,'sup3/gene_rep_COCL2_corr.svg'))
# plt.savefig(os.path.join(fig_path,'sup3/gene_rep_COCL2_corr.jpg'))
# Out:
# PearsonRResult(statistic=0.949859894582376, pvalue=0.0)
# Text(0.25, 0.2, '0.949859894582376')

# %%
sns.scatterplot(data=annotated_gene_editsC_copy, x='NT_mean', y='COCL2_mean', linewidth=0, alpha=0.5, color=custom_palette[5])
# Out:
# <Axes: xlabel='NT_mean', ylabel='COCL2_mean'>

# %%
#annotated_gene_epkm_copy=add_zero_edits(annotated_gene_epkm_copy, 'epkm')

# %%
# annotated_gene_epkm_copy['APO_epkm_mean'] = annotated_gene_epkm_copy.apply(calculate_mean_epkm_apo, axis=1)
# annotated_gene_epkm_copy['RPS2_epkm_mean'] = annotated_gene_epkm_copy.apply(calculate_mean_epkm_rps2, axis=1)

# %%
#annotated_gene_editsC_copy[['editsC_APO_rep1', 'editsC_APO_rep2', 'editsC_APO_rep3', 'editsC_RPS2_rep1', 'editsC_RPS2_rep2', 'editsC_RPS2_rep3', 'APO1_1', 'APO1_2', 'APO1_3', 'RPS2_1', 'RPS2_2', 'RPS2_3']]

# %%
sns.clustermap(annotated_gene_editsC_copy[[i for i in annotated_gene_editsC_copy.columns if (('NT' in i) or ('COCL2' in i)) and ('editsC' in i) and ('rep' in i)]].dropna(), cmap='cividis')
# Out:
# /tscc/projects/ps-yeolab4/software/miniconda_tscc2/envs/python3essential-1.99.0/lib/python3.9/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# /tscc/projects/ps-yeolab4/software/miniconda_tscc2/envs/python3essential-1.99.0/lib/python3.9/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
annotated_gene_editsC_copy.head()
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENSG00000000003.15        0.018975        0.021822           0.012334
# ENSG00000000419.14        0.004090        0.008180           0.007669
# ENSG00000000460.17        0.000738        0.000738                NaN
# ENSG00000000971.16        0.015140        0.009084           0.003785
# ENSG00000001036.14        0.054012        0.094136           0.095679
#
#                     editsC_COCL2_rep2 gene_name       gene_type  \
# ENSG00000000003.15           0.024668    TSPAN6  protein_coding
# ENSG00000000419.14           0.006646      DPM1  protein_coding
# ENSG00000000460.17                NaN  C1orf112  protein_coding
# ENSG00000000971.16           0.006056       CFH  protein_coding
# ENSG00000001036.14           0.098765     FUCA2  protein_coding
#
#                     ensembl_gene_id    baseMean  log2FoldChange     lfcSE  \
# ENSG00000000003.15  ENSG00000000003   84.179709       -0.529452  0.386774
# ...

# %%
sns.displot(annotated_gene_editsC_copy['NT_mean'])

# %%
sns.displot(annotated_gene_editsC_copy['COCL2_mean'])

# %%
sr_data.shape
# Out:
# (64, 19)

# %%
sr_lr_merge = annotated_gene_editsC_copy.merge(sr_data, left_on='gene_name', right_on='gene_name', suffixes=['_LR', '_SR'])

# %%
sr_lr_merge.head()
# Out:
#    editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  editsC_COCL2_rep2  \
# 0        0.016098        0.023181           0.029620           0.018674
# 1        0.000331        0.002319           0.000331           0.001987
# 2        0.011896        0.002099           0.003499           0.004199
# 3        0.002662        0.003549           0.002662           0.001775
# 4        0.000513        0.002050           0.002050           0.001025
#
#   gene_name       gene_type  ensembl_gene_id  baseMean_LR  log2FoldChange_LR  \
# 0      CD74  protein_coding  ENSG00000019582   396.756961           0.280747
# 1  ATP6V0A1  protein_coding  ENSG00000033627          NaN                NaN
# 2     NSMAF  protein_coding  ENSG00000035681    36.013567          -0.947475
# 3    MAP2K4  protein_coding  ENSG00000065559          NaN                NaN
# 4    ATP2B1  protein_coding  ENSG00000070961          NaN                NaN
#
# ...

# %%
sr_lr_merge.columns
# Out:
# Index(['editsC_NT_rep1', 'editsC_NT_rep2', 'editsC_COCL2_rep1',
#        'editsC_COCL2_rep2', 'gene_name', 'gene_type', 'ensembl_gene_id',
#        'baseMean_LR', 'log2FoldChange_LR', 'lfcSE_LR', 'stat_LR', 'pvalue_LR',
#        'padj_LR', '231_NT_rep1', 'Length', '231_NT_rep1_RPKM',
#        '231_cocl2_rep1', 'Length', '231_cocl2_rep1_RPKM', '231_NT_rep2',
#        'Length', '231_NT_rep2_RPKM', '231_cocl2_rep2', 'Length',
#        '231_cocl2_rep2_RPKM', 'NT_mean', 'COCL2_mean', '231_RPS2_1',
#        '231_RPS2_2', '231_RPS2_3', '231_RPS2_CoCl2_1', '231_RPS2_CoCl2_2',
#        '231_RPS2_CoCl2_3', 'statistic', 'baseMean_SR', 'log2FoldChange_SR',
#        'stat_SR', 'padj_SR', 'log10adj_pval', 'epr_ratio', 'pvalue_SR',
#        'lfcSE_SR', 'pvalue_deseq2', '231_NT_mean_SR', '231_COCL2_mean_SR'],
#       dtype='object')

# %%
from scipy.stats import pearsonr, spearmanr

# %%
fig, axes = plt.subplots(1, 2, sharey=False, figsize=(10, 4))

sns.scatterplot(data=sr_lr_merge, x='231_NT_mean_SR', y='NT_mean', ax=axes[0])
sns.scatterplot(data=sr_lr_merge, x='231_COCL2_mean_SR', y='COCL2_mean', ax=axes[1])
print(spearmanr(sr_lr_merge.dropna()['231_NT_mean_SR'], sr_lr_merge.dropna()['NT_mean']))
print(spearmanr(sr_lr_merge.dropna()['231_COCL2_mean_SR'], sr_lr_merge.dropna()['COCL2_mean']))
axes[0].set_title('No Treatment')
axes[1].set_title('COCL2')
axes[0].tick_params(labelrotation=45)
axes[1].tick_params(labelrotation=45)
# Out:
# SignificanceResult(statistic=0.5742124369102247, pvalue=0.006484628634838185)
# SignificanceResult(statistic=0.5662337662337662, pvalue=0.0074528038366745136)

# %%
fig, axes = plt.subplots(1, 2, sharey=False)
sns.violinplot(sr_lr_merge[['231_NT_mean_SR', '231_COCL2_mean_SR']], ax=axes[0])
sns.stripplot(sr_lr_merge[['231_NT_mean_SR', '231_COCL2_mean_SR']], ax=axes[0])
sns.violinplot(sr_lr_merge[['NT_mean', 'COCL2_mean']], ax=axes[1])
sns.stripplot(sr_lr_merge[['NT_mean', 'COCL2_mean']], ax=axes[1])

axes[0].tick_params(labelrotation=90)
axes[1].tick_params(labelrotation=90)
axes[0].set_title('Short Read')
axes[1].set_title('Long Read')
# Out:
# Text(0.5, 1.0, 'Long Read')

# %%
annotated_gene_editsC_copy.columns
# Out:
# Index(['editsC_NT_rep1', 'editsC_NT_rep2', 'editsC_COCL2_rep1',
#        'editsC_COCL2_rep2', 'gene_name', 'gene_type', 'ensembl_gene_id',
#        'baseMean', 'log2FoldChange', 'lfcSE', 'stat', 'pvalue', 'padj',
#        '231_NT_rep1', 'Length', '231_NT_rep1_RPKM', '231_cocl2_rep1', 'Length',
#        '231_cocl2_rep1_RPKM', '231_NT_rep2', 'Length', '231_NT_rep2_RPKM',
#        '231_cocl2_rep2', 'Length', '231_cocl2_rep2_RPKM', 'NT_mean',
#        'COCL2_mean'],
#       dtype='object')

# %%
annotated_gene_editsC_copy['NT_RPKM_mean'] = annotated_gene_editsC_copy.apply(lambda x: np.mean([x['231_NT_rep1_RPKM'], x['231_NT_rep2_RPKM']]), axis=1)
annotated_gene_editsC_copy['COCL2_RPKM_mean']= annotated_gene_editsC_copy.apply(lambda x: np.mean([x['231_cocl2_rep1_RPKM'], x['231_cocl2_rep2_RPKM']]), axis=1)

# %%
from scipy.stats import ttest_ind

# %%
annotated_gene_editsC_copy_2 = annotated_gene_editsC_copy.copy()

# %%
annotated_gene_editsC_copy_2 = annotated_gene_editsC_copy_2.dropna()

# %%
annotated_gene_editsC_copy_2.shape
# Out:
# (4384, 29)

# %%
# setting coverage threshold, but this didn't change anything
annotated_gene_editsC_copy_2 = annotated_gene_editsC_copy_2[(annotated_gene_editsC_copy_2['231_cocl2_rep1']>=10) & (annotated_gene_editsC_copy_2['231_cocl2_rep2']>=10) & (annotated_gene_editsC_copy_2['231_NT_rep1']>=10) & (annotated_gene_editsC_copy_2['231_NT_rep2']>=10)]

# %%
annotated_gene_editsC_copy_2['edit_FC'] = (annotated_gene_editsC_copy_2['COCL2_mean'])/(annotated_gene_editsC_copy_2['NT_mean'])

# %%
annotated_gene_editsC_copy_2['edit_logFC'] = np.log2(annotated_gene_editsC_copy_2['edit_FC'])
# Out:
# /tscc/projects/ps-yeolab4/software/miniconda_tscc2/envs/python3essential-1.99.0/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
annotated_gene_editsC_copy_2[annotated_gene_editsC_copy_2['gene_name'].str.contains('HIF')]
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENSG00000100644.17        0.082067        0.045593           0.033435
# ENSG00000166135.14        0.009558        0.006262           0.010877
#
#                     editsC_COCL2_rep2 gene_name       gene_type  \
# ENSG00000100644.17           0.038501     HIF1A  protein_coding
# ENSG00000166135.14           0.010218    HIF1AN  protein_coding
#
#                     ensembl_gene_id    baseMean  log2FoldChange     lfcSE  \
# ENSG00000100644.17  ENSG00000100644  134.568873       -1.286195  0.358268
# ENSG00000166135.14  ENSG00000166135  154.063781       -0.243481  0.309872
#
#                     ...  231_NT_rep2_RPKM  231_cocl2_rep2   Length  \
# ENSG00000100644.17  ...          2.527714            90.0  52747.0
# ENSG00000166135.14  ...          4.032962           130.0  30927.0
#
#                     231_cocl2_rep2_RPKM  NT_mean  COCL2_mean  NT_RPKM_mean  \
# ...

# %%
# removing FC calculations with 0 in the denominator
annotated_gene_editsC_copy_2_filtered = annotated_gene_editsC_copy_2[(annotated_gene_editsC_copy_2['edit_logFC'] != float('inf')) & (annotated_gene_editsC_copy_2['edit_logFC'] != -float('inf'))].sort_values(by=('edit_logFC'), ascending=False)#[annotated_gene_editsC_copy_2['gene_name'].isin(sr_data['gene_name'])]

# %%
annotated_gene_editsC_copy_2_filtered.sort_values(by=['edit_logFC'], ascending=False)
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENSG00000078967.13        0.000000        0.000845           0.004227
# ENSG00000175183.10        0.000880        0.001759           0.007916
# ENSG00000198841.4         0.000000        0.003650           0.010949
# ENSG00000104979.9         0.008152        0.002717           0.035326
# ENSG00000229833.10        0.002169        0.002169           0.013015
# ...                            ...             ...                ...
# ENSG00000011007.12        0.007037        0.004691           0.000782
# ENSG00000065491.8         0.013393        0.004464           0.002232
# ENSG00000162063.13        0.004384        0.000548           0.000000
# ENSG00000182446.14        0.004423        0.004423           0.000402
# ENSG00000166949.17        0.003125        0.001953           0.000000
#
#                     editsC_COCL2_rep2 gene_name       gene_type  \
# ...

# %%
annotated_gene_editsC_copy_2_filtered['sig_edit_logFC'] = np.abs(annotated_gene_editsC_copy_2_filtered['edit_logFC'])>1.5

# %%
up_translated = annotated_gene_editsC_copy_2_filtered[annotated_gene_editsC_copy_2_filtered['edit_logFC']>1.5]

# %%
down_translated = annotated_gene_editsC_copy_2_filtered[annotated_gene_editsC_copy_2_filtered['edit_logFC']<-1.5]

# %%
sns.scatterplot(x=annotated_gene_editsC_copy_2_filtered['log2FoldChange'], y=-np.log(annotated_gene_editsC_copy_2_filtered['padj']), hue=annotated_gene_editsC_copy_2_filtered['edit_logFC'], linewidth=0)
# Out:
# <Axes: xlabel='log2FoldChange', ylabel='padj'>

# %%
sns.set(rc={'figure.figsize':(2,5)})
sns.set_style('white')
sns.boxplot(annotated_gene_editsC_copy[['NT_mean', 'COCL2_mean']].dropna(), palette=custom_palette)
#sns.stripplot(annotated_gene_editsC_copy[['NT_mean', 'COCL2_mean']].dropna(), palette=custom_palette, alpha=0.3)
#plt.yscale('log')
# plt.savefig(os.path.join(fig_path,'fig4/overall_cocl2_wt_compare.png'))
# plt.savefig(os.path.join(fig_path,'fig4/overall_cocl2_wt_compare.svg'))
# plt.savefig(os.path.join(fig_path,'fig4/overall_cocl2_wt_compare.jpg'))
# Out:
# /tmp/ipykernel_3989180/4037485050.py:3: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.boxplot(annotated_gene_editsC_copy[['NT_mean', 'COCL2_mean']].dropna(), palette=custom_palette)
# <Axes: >

# %%
stats.ranksums(annotated_gene_editsC_copy.dropna()['NT_mean'],annotated_gene_editsC_copy.dropna()['COCL2_mean'] )
# Out:
# RanksumsResult(statistic=-1.6416042376303273, pvalue=0.10067204888933429)

# %%
annotated_gene_editsC_copy_2[annotated_gene_editsC_copy['COCL2_mean'] >0.15]
# Out:
# /tmp/ipykernel_3989180/3645439032.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   annotated_gene_editsC_copy_2[annotated_gene_editsC_copy['COCL2_mean'] >0.15]
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENSG00000005022.6         0.062670        0.122616           0.177112
# ENSG00000087086.15        0.089552        0.126866           0.268657
# ENSG00000110955.9         0.105263        0.136116           0.172414
# ENSG00000117399.14        0.109966        0.134021           0.154639
# ENSG00000118705.17        0.136364        0.147727           0.154830
# ENSG00000125356.7         0.082192        0.205479           0.178082
# ENSG00000127884.5         0.065574        0.103825           0.155738
# ENSG00000170315.14        0.053221        0.114846           0.173669
# ENSG00000188229.6         0.092562        0.127273           0.173554
# ENSG00000198712.1         0.071749        0.116592           0.197309
# ...

# %%
annotated_gene_editsC_copy_2['ttest_pval'] = annotated_gene_editsC_copy_2.apply(lambda x: stats.ttest_ind([x['editsC_NT_rep1'], x['editsC_NT_rep1']], [x['editsC_COCL2_rep1'], x['editsC_COCL2_rep2']])[1], axis=1)
# Out:
# /tscc/projects/ps-yeolab4/software/miniconda_tscc2/envs/python3essential-1.99.0/lib/python3.9/site-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
sns.histplot(annotated_gene_editsC_copy_2['ttest_pval'])
# Out:
# <Axes: xlabel='ttest_pval', ylabel='Count'>

# %%
annotated_gene_editsC_copy_2[annotated_gene_editsC_copy_2['gene_name']=='CISD1']
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENSG00000122873.12        0.008677        0.010846             0.0282
#
#                     editsC_COCL2_rep2 gene_name       gene_type  \
# ENSG00000122873.12             0.0282     CISD1  protein_coding
#
#                     ensembl_gene_id   baseMean  log2FoldChange     lfcSE  ...  \
# ENSG00000122873.12  ENSG00000122873  85.577434        0.548924  0.365089  ...
#
#                     231_cocl2_rep2   Length  231_cocl2_rep2_RPKM   NT_mean  \
# ENSG00000122873.12            94.0  20425.0             4.059934  0.009761
#
#                     COCL2_mean  NT_RPKM_mean  COCL2_RPKM_mean   edit_FC  \
# ENSG00000122873.12      0.0282      2.976393         4.129467  2.888889
#
#                     edit_logFC  ttest_pval
# ENSG00000122873.12    1.530515         0.0
#
# [1 rows x 32 columns]

# %%
fig, axes = plt.subplots(2, 1, sharey=False, figsize=(2,6),sharex=True)
CISD1_toplot = annotated_gene_editsC_copy[annotated_gene_editsC_copy['gene_name']=='CISD1']
sns.barplot(pd.DataFrame([['NT', CISD1_toplot.loc['ENSG00000122873.12','editsC_NT_rep1'], CISD1_toplot.loc['ENSG00000122873.12','editsC_NT_rep2']], ['COCL2', CISD1_toplot.loc['ENSG00000122873.12','editsC_COCL2_rep1'], CISD1_toplot.loc['ENSG00000122873.12','editsC_COCL2_rep2']]]).set_index(0).T, ax=axes[0], palette=custom_palette)
sns.barplot(pd.DataFrame([['NT', CISD1_toplot.loc['ENSG00000122873.12','231_NT_rep1_RPKM'], CISD1_toplot.loc['ENSG00000122873.12','231_NT_rep2_RPKM']], ['COCL2', CISD1_toplot.loc['ENSG00000122873.12','231_cocl2_rep1_RPKM'], CISD1_toplot.loc['ENSG00000122873.12','231_cocl2_rep2_RPKM']]]).set_index(0).T, ax=axes[1], palette=custom_palette)
fig.suptitle('CISD1')
axes[0].set_ylabel('editsC')
axes[1].set_ylabel('RPKM')
# plt.savefig(os.path.join(fig_path,'fig4/cisd1_barplot.png'))
# plt.savefig(os.path.join(fig_path,'fig4/cisd1_barplot.svg'))
# plt.savefig(os.path.join(fig_path,'fig4/cisd1_barplot.jpg'))
# Out:
# /tmp/ipykernel_3989180/2343581045.py:3: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.barplot(pd.DataFrame([['NT', CISD1_toplot.loc['ENSG00000122873.12','editsC_NT_rep1'], CISD1_toplot.loc['ENSG00000122873.12','editsC_NT_rep2']], ['COCL2', CISD1_toplot.loc['ENSG00000122873.12','editsC_COCL2_rep1'], CISD1_toplot.loc['ENSG00000122873.12','editsC_COCL2_rep2']]]).set_index(0).T, ax=axes[0], palette=custom_palette)
# /tmp/ipykernel_3989180/2343581045.py:4: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.barplot(pd.DataFrame([['NT', CISD1_toplot.loc['ENSG00000122873.12','231_NT_rep1_RPKM'], CISD1_toplot.loc['ENSG00000122873.12','231_NT_rep2_RPKM']], ['COCL2', CISD1_toplot.loc['ENSG00000122873.12','231_cocl2_rep1_RPKM'], CISD1_toplot.loc['ENSG00000122873.12','231_cocl2_rep2_RPKM']]]).set_index(0).T, ax=axes[1], palette=custom_palette)
# Text(0, 0.5, 'RPKM')

# %%
stats.ttest_ind([CISD1_toplot.loc['ENSG00000122873.12','editsC_NT_rep1'], CISD1_toplot.loc['ENSG00000122873.12','editsC_NT_rep2']], [CISD1_toplot.loc['ENSG00000122873.12','editsC_COCL2_rep1'], CISD1_toplot.loc['ENSG00000122873.12','editsC_COCL2_rep2']])
# Out:
# /tscc/projects/ps-yeolab4/software/miniconda_tscc2/envs/python3essential-1.99.0/lib/python3.9/site-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# TtestResult(statistic=-17.0, pvalue=0.0034423510070664136, df=2.0)

# %%
annotated_gene_editsC_copy_2[annotated_gene_editsC_copy_2['gene_name']=='CISD1']
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENSG00000122873.12        0.008677        0.010846             0.0282
#
#                     editsC_COCL2_rep2 gene_name       gene_type  \
# ENSG00000122873.12             0.0282     CISD1  protein_coding
#
#                     ensembl_gene_id   baseMean  log2FoldChange     lfcSE  ...  \
# ENSG00000122873.12  ENSG00000122873  85.577434        0.548924  0.365089  ...
#
#                     231_cocl2_rep2   Length  231_cocl2_rep2_RPKM   NT_mean  \
# ENSG00000122873.12            94.0  20425.0             4.059934  0.009761
#
#                     COCL2_mean  NT_RPKM_mean  COCL2_RPKM_mean   edit_FC  \
# ENSG00000122873.12      0.0282      2.976393         4.129467  2.888889
#
#                     edit_logFC  ttest_pval
# ENSG00000122873.12    1.530515         0.0
#
# [1 rows x 32 columns]

# %%
annotated_gene_editsC_copy_2[annotated_gene_editsC_copy_2['gene_name']=='EIF4E'][['padj', 'ttest_pval']]
# Out:
#                         padj  ttest_pval
# ENSG00000151247.13  0.004044    0.046002

# %%
annotated_gene_editsC_copy_2[annotated_gene_editsC_copy_2['gene_name']=='EIF4E2'][['padj', 'ttest_pval']]
# Out:
#                         padj  ttest_pval
# ENSG00000135930.14  0.520496    0.005865

# %%
annotated_gene_editsC_copy_2[annotated_gene_editsC_copy_2['gene_name']=='HIF1A'][['padj', 'ttest_pval']]
# Out:
#                        padj  ttest_pval
# ENSG00000100644.17  0.00378    0.003005

# %%
annotated_gene_editsC_copy_2[((np.abs(annotated_gene_editsC_copy_2['edit_logFC']) >=1) & (annotated_gene_editsC_copy_2['ttest_pval'] <= 0.05)) & ((np.abs(annotated_gene_editsC_copy_2['log2FoldChange']) <1) & (annotated_gene_editsC_copy_2['padj'] > 0.05))].sort_values(by=['ttest_pval', 'edit_logFC'], ascending=[True, False]).dropna().head(20)
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENSG00000198840.2         0.000000        0.000000           0.000530
# ENSG00000129355.7         0.001908        0.001908           0.005725
# ENSG00000198912.12        0.000808        0.000808           0.002423
# ENSG00000123595.8         0.000000        0.005063           0.007595
# ENSG00000122873.12        0.008677        0.010846           0.028200
# ENSG00000133142.18        0.009862        0.009862           0.027613
# ENSG00000002587.10        0.001746        0.000582           0.002910
# ENSG00000145050.19        0.006073        0.012146           0.022267
# ENSG00000131669.10        0.004280        0.004280           0.009986
# ENSG00000163463.13        0.003148        0.010493           0.015740
# ENSG00000117305.15        0.002656        0.006640           0.009960
# ENSG00000114942.14        0.025707        0.028278           0.056555
# ...

# %%
annotated_gene_editsC_copy_2[((np.abs(annotated_gene_editsC_copy_2['edit_logFC']) >=1) & (annotated_gene_editsC_copy_2['ttest_pval'] <= 0.05)) & ((np.abs(annotated_gene_editsC_copy_2['log2FoldChange']) <1) & (annotated_gene_editsC_copy_2['padj'] > 0.05))].sort_values(by=['ttest_pval', 'edit_logFC'], ascending=[True, False]).dropna().head(20).loc['ENSG00000122873.12', 'ttest_pval']
# Out:
# 0.0

# %%
fig, axes = plt.subplots(2, 1, sharey=False, figsize=(2,6),sharex=True)
PGP_toplot = annotated_gene_editsC_copy[annotated_gene_editsC_copy['gene_name']=='PGP']
sns.barplot(pd.DataFrame([['NT', PGP_toplot.loc['ENSG00000184207.9','editsC_NT_rep1'], PGP_toplot.loc['ENSG00000184207.9','editsC_NT_rep2']], ['COCL2', PGP_toplot.loc['ENSG00000184207.9','editsC_COCL2_rep1'], PGP_toplot.loc['ENSG00000184207.9','editsC_COCL2_rep2']]]).set_index(0).T, ax=axes[0], palette=custom_palette)
sns.barplot(pd.DataFrame([['NT', PGP_toplot.loc['ENSG00000184207.9','231_NT_rep1_RPKM'], PGP_toplot.loc['ENSG00000184207.9','231_NT_rep2_RPKM']], ['COCL2', PGP_toplot.loc['ENSG00000184207.9','231_cocl2_rep1_RPKM'], PGP_toplot.loc['ENSG00000184207.9','231_cocl2_rep2_RPKM']]]).set_index(0).T, ax=axes[1], palette=custom_palette)
fig.suptitle('PGP')
axes[0].set_ylabel('editsC')
axes[1].set_ylabel('RPKM')
# plt.savefig(os.path.join(fig_path,'fig4/pgp_barplot.png'))
# plt.savefig(os.path.join(fig_path,'fig4/pgp_barplot.svg'))
# plt.savefig(os.path.join(fig_path,'fig4/pgp_barplot.jpg'))
# Out:
# /tmp/ipykernel_3989180/2713579898.py:3: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.barplot(pd.DataFrame([['NT', PGP_toplot.loc['ENSG00000184207.9','editsC_NT_rep1'], PGP_toplot.loc['ENSG00000184207.9','editsC_NT_rep2']], ['COCL2', PGP_toplot.loc['ENSG00000184207.9','editsC_COCL2_rep1'], PGP_toplot.loc['ENSG00000184207.9','editsC_COCL2_rep2']]]).set_index(0).T, ax=axes[0], palette=custom_palette)
# /tmp/ipykernel_3989180/2713579898.py:4: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.barplot(pd.DataFrame([['NT', PGP_toplot.loc['ENSG00000184207.9','231_NT_rep1_RPKM'], PGP_toplot.loc['ENSG00000184207.9','231_NT_rep2_RPKM']], ['COCL2', PGP_toplot.loc['ENSG00000184207.9','231_cocl2_rep1_RPKM'], PGP_toplot.loc['ENSG00000184207.9','231_cocl2_rep2_RPKM']]]).set_index(0).T, ax=axes[1], palette=custom_palette)
# Text(0, 0.5, 'RPKM')

# %%
for gName in ['HIF1A', 'EIF4E', 'EIF4E2', 'CISD1']:
    sns.set(rc={'figure.figsize':(3,5)})
    sns.set_style('white')
    #gName='PGP'
    gName_toplot = annotated_gene_editsC_copy[annotated_gene_editsC_copy['gene_name']==gName]
    gName_toplot = gName_toplot.set_index('gene_name')
    rep1_NT_TE = gName_toplot.loc[gName,'editsC_NT_rep1']/gName_toplot.loc[gName,'231_NT_rep1_RPKM']
    rep2_NT_TE = gName_toplot.loc[gName,'editsC_NT_rep2']/gName_toplot.loc[gName,'231_NT_rep2_RPKM']
    rep1_cocl2_TE = gName_toplot.loc[gName,'editsC_COCL2_rep1']/gName_toplot.loc[gName,'231_cocl2_rep1_RPKM']
    rep2_cocl2_TE = gName_toplot.loc[gName,'editsC_COCL2_rep2']/gName_toplot.loc[gName,'231_cocl2_rep2_RPKM']
    
    sns.barplot(pd.DataFrame([['NT', rep1_NT_TE, rep2_NT_TE], 
                             ['COCL2', rep1_cocl2_TE, rep2_cocl2_TE]]).set_index(0).T, palette=custom_palette)
    print(stats.ttest_ind([rep1_NT_TE, rep2_NT_TE], [rep1_cocl2_TE, rep2_cocl2_TE]))
    plt.title(gName)
    plt.ylabel('EditsC/RPKM')
    # plt.savefig(os.path.join(fig_path,f'fig4/{gName}_TE_barplot.png'))
    # plt.savefig(os.path.join(fig_path,f'fig4/{gName}_TE_barplot.svg'))
    # plt.savefig(os.path.join(fig_path,f'fig4/{gName}_TE_barplot.jpg'))
    plt.show()
# Out:
# /tmp/ipykernel_3989180/733294250.py:12: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.barplot(pd.DataFrame([['NT', rep1_NT_TE, rep2_NT_TE],
# TtestResult(statistic=-2.0339624817282935, pvalue=0.17895916689406746, df=2.0)
# /tmp/ipykernel_3989180/733294250.py:12: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.barplot(pd.DataFrame([['NT', rep1_NT_TE, rep2_NT_TE],
# TtestResult(statistic=-1.1577070200249424, pvalue=0.3665579794517936, df=2.0)
# /tmp/ipykernel_3989180/733294250.py:12: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.barplot(pd.DataFrame([['NT', rep1_NT_TE, rep2_NT_TE],
# TtestResult(statistic=-0.891795051014885, pvalue=0.46660250848016305, df=2.0)
# /tmp/ipykernel_3989180/733294250.py:12: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
# ...

# %%
fig, axes = plt.subplots(2, 1, sharey=False, figsize=(2,6),sharex=True)
FTL_toplot = annotated_gene_editsC_copy[annotated_gene_editsC_copy['gene_name']=='FTL']
sns.barplot(pd.DataFrame([['NT', FTL_toplot.loc['ENSG00000087086.15','editsC_NT_rep1'], FTL_toplot.loc['ENSG00000087086.15','editsC_NT_rep2']], ['COCL2', FTL_toplot.loc['ENSG00000087086.15','editsC_COCL2_rep1'], FTL_toplot.loc['ENSG00000087086.15','editsC_COCL2_rep2']]]).set_index(0).T, ax=axes[0], palette=custom_palette)
sns.barplot(pd.DataFrame([['NT', FTL_toplot.loc['ENSG00000087086.15','231_NT_rep1_RPKM'], FTL_toplot.loc['ENSG00000087086.15','231_NT_rep2_RPKM']], ['COCL2', FTL_toplot.loc['ENSG00000087086.15','231_cocl2_rep1_RPKM'], FTL_toplot.loc['ENSG00000087086.15','231_cocl2_rep2_RPKM']]]).set_index(0).T, ax=axes[1], palette=custom_palette)
fig.suptitle('FTL')
axes[0].set_ylabel('editsC')
axes[1].set_ylabel('RPKM')
# plt.savefig(os.path.join(fig_path,'sup3/FTL_barplot.png'))
# plt.savefig(os.path.join(fig_path,'sup3/FTL_barplot.svg'))
# plt.savefig(os.path.join(fig_path,'sup3/FTL_barplot.jpg'))
# Out:
# /tmp/ipykernel_3989180/2243411360.py:3: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.barplot(pd.DataFrame([['NT', FTL_toplot.loc['ENSG00000087086.15','editsC_NT_rep1'], FTL_toplot.loc['ENSG00000087086.15','editsC_NT_rep2']], ['COCL2', FTL_toplot.loc['ENSG00000087086.15','editsC_COCL2_rep1'], FTL_toplot.loc['ENSG00000087086.15','editsC_COCL2_rep2']]]).set_index(0).T, ax=axes[0], palette=custom_palette)
# /tmp/ipykernel_3989180/2243411360.py:4: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.barplot(pd.DataFrame([['NT', FTL_toplot.loc['ENSG00000087086.15','231_NT_rep1_RPKM'], FTL_toplot.loc['ENSG00000087086.15','231_NT_rep2_RPKM']], ['COCL2', FTL_toplot.loc['ENSG00000087086.15','231_cocl2_rep1_RPKM'], FTL_toplot.loc['ENSG00000087086.15','231_cocl2_rep2_RPKM']]]).set_index(0).T, ax=axes[1], palette=custom_palette)
# Text(0, 0.5, 'RPKM')

# %%
annotated_gene_editsC_copy[annotated_gene_editsC_copy['gene_name']=='EIF4E2']
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENSG00000135930.14        0.002809         0.00632           0.007725
#
#                     editsC_COCL2_rep2 gene_name       gene_type  \
# ENSG00000135930.14           0.007022    EIF4E2  protein_coding
#
#                     ensembl_gene_id   baseMean  log2FoldChange     lfcSE  ...  \
# ENSG00000135930.14  ENSG00000135930  71.012713         0.31181  0.388739  ...
#
#                     231_NT_rep2   Length  231_NT_rep2_RPKM  231_cocl2_rep2  \
# ENSG00000135930.14         63.0  32971.0          1.643624            71.0
#
#                      Length  231_cocl2_rep2_RPKM   NT_mean  COCL2_mean  \
# ENSG00000135930.14  32971.0             1.899675  0.004565    0.007374
#
#                     NT_RPKM_mean  COCL2_RPKM_mean
# ENSG00000135930.14      1.674545         1.977936
#
# [1 rows x 29 columns]

# %%
fig, axes = plt.subplots(2, 1, sharey=False, figsize=(2,6),sharex=True)
EIF4E2_toplot = annotated_gene_editsC_copy[annotated_gene_editsC_copy['gene_name']=='EIF4E2']
sns.barplot(pd.DataFrame([['NT', EIF4E2_toplot.loc['ENSG00000135930.14','editsC_NT_rep1'], EIF4E2_toplot.loc['ENSG00000135930.14','editsC_NT_rep2']], ['COCL2', EIF4E2_toplot.loc['ENSG00000135930.14','editsC_COCL2_rep1'], EIF4E2_toplot.loc['ENSG00000135930.14','editsC_COCL2_rep2']]]).set_index(0).T, ax=axes[0], palette=custom_palette)
sns.barplot(pd.DataFrame([['NT', EIF4E2_toplot.loc['ENSG00000135930.14','231_NT_rep1_RPKM'], EIF4E2_toplot.loc['ENSG00000135930.14','231_NT_rep2_RPKM']], ['COCL2', EIF4E2_toplot.loc['ENSG00000135930.14','231_cocl2_rep1_RPKM'], EIF4E2_toplot.loc['ENSG00000135930.14','231_cocl2_rep2_RPKM']]]).set_index(0).T, ax=axes[1], palette=custom_palette)
fig.suptitle('EIF4E2')
axes[0].set_ylabel('editsC')
axes[1].set_ylabel('RPKM')
# plt.savefig(os.path.join(fig_path,'fig4/EIF4E2_barplot.png'))
# plt.savefig(os.path.join(fig_path,'fig4/EIF4E2_barplot.svg'))
# plt.savefig(os.path.join(fig_path,'fig4/EIF4E2_barplot.jpg'))
# Out:
# /tmp/ipykernel_3989180/2871394365.py:3: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.barplot(pd.DataFrame([['NT', EIF4E2_toplot.loc['ENSG00000135930.14','editsC_NT_rep1'], EIF4E2_toplot.loc['ENSG00000135930.14','editsC_NT_rep2']], ['COCL2', EIF4E2_toplot.loc['ENSG00000135930.14','editsC_COCL2_rep1'], EIF4E2_toplot.loc['ENSG00000135930.14','editsC_COCL2_rep2']]]).set_index(0).T, ax=axes[0], palette=custom_palette)
# /tmp/ipykernel_3989180/2871394365.py:4: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.barplot(pd.DataFrame([['NT', EIF4E2_toplot.loc['ENSG00000135930.14','231_NT_rep1_RPKM'], EIF4E2_toplot.loc['ENSG00000135930.14','231_NT_rep2_RPKM']], ['COCL2', EIF4E2_toplot.loc['ENSG00000135930.14','231_cocl2_rep1_RPKM'], EIF4E2_toplot.loc['ENSG00000135930.14','231_cocl2_rep2_RPKM']]]).set_index(0).T, ax=axes[1], palette=custom_palette)
# Text(0, 0.5, 'RPKM')

# %%
annotated_gene_editsC_copy[annotated_gene_editsC_copy['gene_name']=='HIF1A']
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENSG00000100644.17        0.082067        0.045593           0.033435
#
#                     editsC_COCL2_rep2 gene_name       gene_type  \
# ENSG00000100644.17           0.038501     HIF1A  protein_coding
#
#                     ensembl_gene_id    baseMean  log2FoldChange     lfcSE  \
# ENSG00000100644.17  ENSG00000100644  134.568873       -1.286195  0.358268
#
#                     ...  231_NT_rep2   Length  231_NT_rep2_RPKM  \
# ENSG00000100644.17  ...        155.0  52747.0          2.527714
#
#                     231_cocl2_rep2   Length  231_cocl2_rep2_RPKM  NT_mean  \
# ENSG00000100644.17            90.0  52747.0             1.505213  0.06383
#
#                     COCL2_mean  NT_RPKM_mean  COCL2_RPKM_mean
# ENSG00000100644.17    0.035968      3.133543         1.232652
#
# [1 rows x 29 columns]

# %%
fig, axes = plt.subplots(2, 1, sharey=False, figsize=(2,6),sharex=True)
HIF1A_toplot = annotated_gene_editsC_copy[annotated_gene_editsC_copy['gene_name']=='HIF1A']
sns.barplot(pd.DataFrame([['NT', HIF1A_toplot.loc['ENSG00000100644.17','editsC_NT_rep1'], HIF1A_toplot.loc['ENSG00000100644.17','editsC_NT_rep2']], ['COCL2', HIF1A_toplot.loc['ENSG00000100644.17','editsC_COCL2_rep1'], HIF1A_toplot.loc['ENSG00000100644.17','editsC_COCL2_rep2']]]).set_index(0).T, ax=axes[0], palette=custom_palette)
sns.barplot(pd.DataFrame([['NT', HIF1A_toplot.loc['ENSG00000100644.17','231_NT_rep1_RPKM'], HIF1A_toplot.loc['ENSG00000100644.17','231_NT_rep2_RPKM']], ['COCL2', HIF1A_toplot.loc['ENSG00000100644.17','231_cocl2_rep1_RPKM'], HIF1A_toplot.loc['ENSG00000100644.17','231_cocl2_rep2_RPKM']]]).set_index(0).T, ax=axes[1], palette=custom_palette)
fig.suptitle('HIF1A')
axes[0].set_ylabel('editsC')
axes[1].set_ylabel('RPKM')
# plt.savefig(os.path.join(fig_path,'sup3/HIFA_barplot.png'))
# plt.savefig(os.path.join(fig_path,'sup3/HIFA_barplot.svg'))
# plt.savefig(os.path.join(fig_path,'sup3/HIFA_barplot.jpg'))
# Out:
# /tmp/ipykernel_3989180/1324767709.py:3: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.barplot(pd.DataFrame([['NT', HIF1A_toplot.loc['ENSG00000100644.17','editsC_NT_rep1'], HIF1A_toplot.loc['ENSG00000100644.17','editsC_NT_rep2']], ['COCL2', HIF1A_toplot.loc['ENSG00000100644.17','editsC_COCL2_rep1'], HIF1A_toplot.loc['ENSG00000100644.17','editsC_COCL2_rep2']]]).set_index(0).T, ax=axes[0], palette=custom_palette)
# /tmp/ipykernel_3989180/1324767709.py:4: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.barplot(pd.DataFrame([['NT', HIF1A_toplot.loc['ENSG00000100644.17','231_NT_rep1_RPKM'], HIF1A_toplot.loc['ENSG00000100644.17','231_NT_rep2_RPKM']], ['COCL2', HIF1A_toplot.loc['ENSG00000100644.17','231_cocl2_rep1_RPKM'], HIF1A_toplot.loc['ENSG00000100644.17','231_cocl2_rep2_RPKM']]]).set_index(0).T, ax=axes[1], palette=custom_palette)
# Text(0, 0.5, 'RPKM')

# %%
fig, axes = plt.subplots(2, 1, sharey=False, figsize=(2,6),sharex=True)
EIF4E_toplot = annotated_gene_editsC_copy[annotated_gene_editsC_copy['gene_name']=='EIF4E']
sns.barplot(pd.DataFrame([['NT', EIF4E_toplot.loc['ENSG00000151247.13','editsC_NT_rep1'], EIF4E_toplot.loc['ENSG00000151247.13','editsC_NT_rep2']], ['COCL2', EIF4E_toplot.loc['ENSG00000151247.13','editsC_COCL2_rep1'], EIF4E_toplot.loc['ENSG00000151247.13','editsC_COCL2_rep2']]]).set_index(0).T, ax=axes[0], palette=custom_palette)
sns.barplot(pd.DataFrame([['NT', EIF4E_toplot.loc['ENSG00000151247.13','231_NT_rep1_RPKM'], EIF4E_toplot.loc['ENSG00000151247.13','231_NT_rep2_RPKM']], ['COCL2', EIF4E_toplot.loc['ENSG00000151247.13','231_cocl2_rep1_RPKM'], EIF4E_toplot.loc['ENSG00000151247.13','231_cocl2_rep2_RPKM']]]).set_index(0).T, ax=axes[1], palette=custom_palette)
fig.suptitle('EIF4E')
axes[0].set_ylabel('editsC')
axes[1].set_ylabel('RPKM')
# plt.savefig(os.path.join(fig_path,'fig4/EIF4E_barplot.png'))
# plt.savefig(os.path.join(fig_path,'fig4/EIF4E_barplot.svg'))
# plt.savefig(os.path.join(fig_path,'fig4/EIF4E_barplot.jpg'))
# Out:
# /tmp/ipykernel_3989180/3985291109.py:3: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.barplot(pd.DataFrame([['NT', EIF4E_toplot.loc['ENSG00000151247.13','editsC_NT_rep1'], EIF4E_toplot.loc['ENSG00000151247.13','editsC_NT_rep2']], ['COCL2', EIF4E_toplot.loc['ENSG00000151247.13','editsC_COCL2_rep1'], EIF4E_toplot.loc['ENSG00000151247.13','editsC_COCL2_rep2']]]).set_index(0).T, ax=axes[0], palette=custom_palette)
# /tmp/ipykernel_3989180/3985291109.py:4: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.barplot(pd.DataFrame([['NT', EIF4E_toplot.loc['ENSG00000151247.13','231_NT_rep1_RPKM'], EIF4E_toplot.loc['ENSG00000151247.13','231_NT_rep2_RPKM']], ['COCL2', EIF4E_toplot.loc['ENSG00000151247.13','231_cocl2_rep1_RPKM'], EIF4E_toplot.loc['ENSG00000151247.13','231_cocl2_rep2_RPKM']]]).set_index(0).T, ax=axes[1], palette=custom_palette)
# Text(0, 0.5, 'RPKM')

# %%
hif_pathway = {'AJUBA',
 'ARNT',
 'CA9',
 'CITED2',
 'CREBBP',
 'CUL2',
 'EGLN1',
 'EGLN2',
 'EGLN3',
 'ELOB',
 'ELOC',
 'EP300',
 'EPAS1',
 'EPO',
 'HIF1A',
 'HIF1AN',
 'HIF3A',
 'HIGD1A',
 'LIMD1',
 'PSMA1',
 'PSMA2',
 'PSMA3',
 'PSMA4',
 'PSMA5',
 'PSMA6',
 'PSMA7',
 'PSMA8',
 'PSMB1',
 'PSMB10',
 'PSMB11',
 'PSMB2',
 'PSMB3',
 'PSMB4',
 'PSMB5',
 'PSMB6',
 'PSMB7',
 'PSMB8',
 'PSMB9',
 'PSMC1',
 'PSMC2',
 'PSMC3',
 'PSMC4',
 'PSMC5',
 'PSMC6',
 'PSMD1',
 'PSMD10',
 'PSMD11',
 'PSMD12',
 'PSMD13',
 'PSMD14',
 'PSMD2',
 'PSMD3',
 'PSMD4',
 'PSMD5',
 'PSMD6',
 'PSMD7',
 'PSMD8',
 'PSMD9',
 'PSME1',
 'PSME2',
 'PSME3',
 'PSME4',
 'PSMF1',
 'RBX1',
 'RPS27A',
 'SEM1',
 'UBA52',
 'UBB',
 'UBC',
 'UBE2D1',
 'UBE2D2',
 'UBE2D3',
 'VEGFA',
 'VHL',
 'WTIP'}

# %%
# sns.clustermap(annotated_gene_editsC_copy[annotated_gene_editsC_copy['gene_name'].isin(hif_pathway)].set_index('gene_name')[['NT_mean', 'COCL2_mean']].dropna(),col_cluster=False, figsize=(3,20), cmap='viridis')
# sns.clustermap(annotated_gene_editsC_copy[annotated_gene_editsC_copy['gene_name'].isin(hif_pathway)].set_index('gene_name')[['NT_RPKM_mean', 'COCL2_RPKM_mean']].dropna(),col_cluster=False, figsize=(3,20), cmap='viridis')

# %%
annotated_gene_editsC_copy[annotated_gene_editsC_copy['gene_name']=='HIF1A']
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENSG00000100644.17        0.082067        0.045593           0.033435
#
#                     editsC_COCL2_rep2 gene_name       gene_type  \
# ENSG00000100644.17           0.038501     HIF1A  protein_coding
#
#                     ensembl_gene_id    baseMean  log2FoldChange     lfcSE  \
# ENSG00000100644.17  ENSG00000100644  134.568873       -1.286195  0.358268
#
#                     ...  231_NT_rep2   Length  231_NT_rep2_RPKM  \
# ENSG00000100644.17  ...        155.0  52747.0          2.527714
#
#                     231_cocl2_rep2   Length  231_cocl2_rep2_RPKM  NT_mean  \
# ENSG00000100644.17            90.0  52747.0             1.505213  0.06383
#
#                     COCL2_mean  NT_RPKM_mean  COCL2_RPKM_mean
# ENSG00000100644.17    0.035968      3.133543         1.232652
#
# [1 rows x 29 columns]

# %%
annotated_gene_editsC_copy_2.dropna()[annotated_gene_editsC_copy_2.dropna()['gene_name'].str.contains('EG')]
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENSG00000109321.11        0.031609        0.043103           0.048851
# ENSG00000113070.8         0.004005        0.004005           0.006676
# ENSG00000129195.16        0.011250        0.008750           0.033750
# ENSG00000135766.9         0.006499        0.011373           0.007311
# ENSG00000143162.9         0.051931        0.041278           0.034621
# ENSG00000143753.13        0.056140        0.071930           0.068421
# ENSG00000144567.11        0.011557        0.012237           0.004759
# ENSG00000172889.16        0.005593        0.010067           0.025727
# ENSG00000269858.6         0.008448        0.009504           0.020063
#
#                     editsC_COCL2_rep2 gene_name       gene_type  \
# ENSG00000109321.11           0.051724      AREG  protein_coding
# ENSG00000113070.8            0.010681     HBEGF  protein_coding
# ENSG00000129195.16           0.022500    PIMREG  protein_coding
# ...

# %%
annotated_gene_editsC_copy_2.dropna()[annotated_gene_editsC_copy_2.dropna()['gene_name'].str.contains('HIF')]
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENSG00000100644.17        0.082067        0.045593           0.033435
# ENSG00000166135.14        0.009558        0.006262           0.010877
#
#                     editsC_COCL2_rep2 gene_name       gene_type  \
# ENSG00000100644.17           0.038501     HIF1A  protein_coding
# ENSG00000166135.14           0.010218    HIF1AN  protein_coding
#
#                     ensembl_gene_id    baseMean  log2FoldChange     lfcSE  \
# ENSG00000100644.17  ENSG00000100644  134.568873       -1.286195  0.358268
# ENSG00000166135.14  ENSG00000166135  154.063781       -0.243481  0.309872
#
#                     ...  231_cocl2_rep2   Length  231_cocl2_rep2_RPKM  \
# ENSG00000100644.17  ...            90.0  52747.0             1.505213
# ENSG00000166135.14  ...           130.0  30927.0             3.708162
#
#                     NT_mean  COCL2_mean  NT_RPKM_mean  COCL2_RPKM_mean  \
# ...

# %%
#annotated_gene_editsC_copy_2.to_csv('annotated_gene_editsC_copy_wsig_jan2024.txt', sep='\t')

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.set_style('white')
sns.scatterplot(x=annotated_gene_editsC_copy_2_filtered['log2FoldChange'], y=-np.log(annotated_gene_editsC_copy_2_filtered['padj']), color='lightgrey',linewidth=0, alpha=0.5)
sns.scatterplot(x=annotated_gene_editsC_copy_2_filtered[annotated_gene_editsC_copy_2_filtered['edit_logFC']>1.0]['log2FoldChange'], y=-np.log10(annotated_gene_editsC_copy_2_filtered[annotated_gene_editsC_copy_2_filtered['edit_logFC']>1.0]['padj']), color='orange',linewidth=0, alpha=0.5)
sns.scatterplot(x=annotated_gene_editsC_copy_2_filtered[annotated_gene_editsC_copy_2_filtered['edit_logFC']<-1.0]['log2FoldChange'], y=-np.log10(annotated_gene_editsC_copy_2_filtered[annotated_gene_editsC_copy_2_filtered['edit_logFC']<-1.0]['padj']), color='purple',linewidth=0, alpha=0.5)
plt.axvline(1.0, color='darkgrey', linestyle='--')
plt.axvline(-1., color='darkgrey', linestyle='--')
plt.axhline(-np.log10(0.05), color='darkgrey', linestyle='--')

# %%
up_translated = annotated_gene_editsC_copy_2_filtered[(annotated_gene_editsC_copy_2_filtered['padj'] > 0.05) & (np.abs(annotated_gene_editsC_copy_2_filtered['log2FoldChange']) < 1.0) & (annotated_gene_editsC_copy_2_filtered['edit_logFC']>=1.0) ]

# %%
down_translated = annotated_gene_editsC_copy_2_filtered[(annotated_gene_editsC_copy_2_filtered['padj'] > 0.05) & (np.abs(annotated_gene_editsC_copy_2_filtered['log2FoldChange']) < 1.0) & (annotated_gene_editsC_copy_2_filtered['edit_logFC']<=-1) ]

# %%
annotated_gene_editsC_copy_2_filtered[annotated_gene_editsC_copy_2_filtered['gene_name'].str.contains('EIF4E')]
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENSG00000187840.5         0.020202        0.043771           0.057239
# ENSG00000135930.14        0.002809        0.006320           0.007725
# ENSG00000151247.13        0.028090        0.032772           0.021536
# ENSG00000148730.7         0.001760        0.002933           0.000587
#
#                     editsC_COCL2_rep2 gene_name       gene_type  \
# ENSG00000187840.5            0.060606  EIF4EBP1  protein_coding
# ENSG00000135930.14           0.007022    EIF4E2  protein_coding
# ENSG00000151247.13           0.017790     EIF4E  protein_coding
# ENSG00000148730.7            0.001173  EIF4EBP2  protein_coding
#
#                     ensembl_gene_id    baseMean  log2FoldChange     lfcSE  \
# ENSG00000187840.5   ENSG00000187840  170.961407        1.219504  0.309666
# ENSG00000135930.14  ENSG00000135930   71.012713        0.311810  0.388739
# ...

# %%
up_translated.sort_values(by=['edit_logFC', 'log2FoldChange'], ascending=[False, True]).head(20)
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENSG00000078967.13        0.000000        0.000845           0.004227
# ENSG00000198841.4         0.000000        0.003650           0.010949
# ENSG00000229833.10        0.002169        0.002169           0.013015
# ENSG00000119986.7         0.002532        0.005063           0.022785
# ENSG00000105829.13        0.000000        0.001043           0.002086
# ENSG00000052723.12        0.001773        0.000887           0.003546
# ENSG00000163882.9         0.002481        0.003722           0.011166
# ENSG00000175197.13        0.006079        0.000000           0.018237
# ENSG00000041988.15        0.000847        0.000847           0.003387
# ENSG00000162384.14        0.002653        0.003537           0.015915
# ENSG00000168785.8         0.000597        0.000597           0.002985
# ENSG00000100744.15        0.000000        0.002255           0.005637
# ...

# %%
deseq2_transcript = pd.read_csv('~/projects/STAMP/stamp_v3_pipeline/notebooks/231_data/231_WT_vs_Cocl2_transcript.csv', index_col=0)

# %%
deseq2_transcript.head()
# Out:
#                         baseMean  log2FoldChange     lfcSE      stat  \
# ENST00000229239.10  13370.494496        1.458477  0.195674  7.453607
# ENST00000368636.8     456.823221        1.528497  0.228768  6.681418
# ENST00000451270.7    4211.088956        1.252401  0.190961  6.558428
# ENST00000643777.4    1959.956274        1.268136  0.196341  6.458846
# ENST00000582743.6    3190.075548        1.107112  0.175511  6.307919
#
#                           pvalue          padj
# ENST00000229239.10  9.082232e-14  5.811720e-10
# ENST00000368636.8   2.366418e-11  7.571354e-08
# ENST00000451270.7   5.437783e-11  1.159879e-07
# ENST00000643777.4   1.055043e-10  1.687806e-07
# ENST00000582743.6   2.828127e-10  3.619437e-07

# %%
down_transcribe_translated = []
for g in annotated_gene_editsC_copy_2_filtered[(annotated_gene_editsC_copy_2_filtered['edit_logFC']<=-1.0) ]['gene_name'].tolist():
    down_transcribe_translated.append(g)
#pd.DataFrame(down_transcribe_translated).to_csv('down_NT_COCL2_up_transcribe_translated.txt', header=None, index=False)

# %%
up_transcribe_translated = []
for g in annotated_gene_editsC_copy_2_filtered[(annotated_gene_editsC_copy_2_filtered['edit_logFC']>=1.0) ]['gene_name'].tolist():
    up_transcribe_translated.append(g)
#pd.DataFrame(up_transcribe_translated).to_csv('up_NT_COCL2_up_transcribe_translated.txt', header=None, index=False)

# %%
#up_translated[['gene_name']].to_csv('up_NT_COCL2_up_translated.txt', header=None, index=False)

# %%
#down_translated[['gene_name']].to_csv('down_NT_COCL2_down_translated.txt', header=None, index=False)

# %%
# annotated_gene_epkm_copy['APO_RPKM_mean'] = annotated_gene_epkm_copy.apply(lambda x: np.mean([x['APO1_1_RPKM'], x['APO1_2_RPKM'], x['APO1_3_RPKM']]), axis=1)
# annotated_gene_epkm_copy['RPS2_RPKM_mean']= annotated_gene_epkm_copy.apply(lambda x: np.mean([x['RPS2_1_RPKM'], x['RPS2_2_RPKM'], x['RPS2_3_RPKM']]), axis=1)

# %%
#annotated_gene_editsC_copy['RPS2_editsC/APO_editsC'] = annotated_gene_editsC_copy['RPS2_mean']/annotated_gene_editsC_copy['APO_mean']

# %%
#annotated_gene_epkm_copy['RPS2_epkm/APO_epkm'] = annotated_gene_epkm_copy['RPS2_epkm_mean']/annotated_gene_epkm_copy['APO_epkm_mean']

# %%
# annotated_gene_editsC_copy['RPS2_editsC/RPS2_RPKM_mean'] = annotated_gene_editsC_copy['RPS2_mean']/annotated_gene_editsC_copy['RPS2_RPKM_mean']
# annotated_gene_editsC_copy['APO_editsC/APO_RPKM_mean'] = annotated_gene_editsC_copy['APO_mean']/annotated_gene_editsC_copy['APO_RPKM_mean']

# %%
# annotated_gene_epkm_copy['RPS2_epkm/RPS2_RPKM_mean'] = annotated_gene_epkm_copy['RPS2_epkm_mean']/annotated_gene_epkm_copy['RPS2_RPKM_mean']
# annotated_gene_epkm_copy['APO_epkm/APO_RPKM_mean'] = annotated_gene_epkm_copy['APO_epkm_mean']/annotated_gene_epkm_copy['APO_RPKM_mean']

# %%
#annotated_gene_editsC_copy[['gene_name', 'editsC_APO_rep1', 'editsC_APO_rep2', 'editsC_APO_rep3','editsC_RPS2_rep1','editsC_RPS2_rep2','editsC_RPS2_rep3', 'APO1_1_RPKM', 'APO1_2_RPKM', 'APO1_3_RPKM', 'RPS2_1_RPKM', 'RPS2_2_RPKM', 'RPS2_3_RPKM']].dropna().set_index('gene_name').to_csv('gene_editsC_forpCA.txt', sep='\t')

# %%
print(stats.spearmanr(annotated_gene_editsC_copy_2[(np.abs(annotated_gene_editsC_copy_2['log2FoldChange'])!= float('inf')) & (np.abs(annotated_gene_editsC_copy_2['edit_logFC'])!= float('inf'))]['log2FoldChange'], annotated_gene_editsC_copy_2[(np.abs(annotated_gene_editsC_copy_2['log2FoldChange'])!= float('inf')) & (np.abs(annotated_gene_editsC_copy_2['edit_logFC'])!= float('inf'))]['edit_logFC']))
# Out:
# SignificanceResult(statistic=0.8469645080176333, pvalue=0.0)

# %%
sns.set(rc={'figure.figsize':(4,4)})
sns.set_style('white')
sns.scatterplot(data=annotated_gene_editsC_copy_2.dropna(), x='log2FoldChange', y='edit_logFC', alpha=0.5, linewidth=0, color='#7E1F86')
print(stats.spearmanr(annotated_gene_editsC_copy_2.dropna()['log2FoldChange'], annotated_gene_editsC_copy_2.dropna()['edit_logFC']))
plt.xlim(-3, 3)
plt.ylim(-4,4)
# plt.savefig(os.path.join(fig_path,'sup3/stamp_gene_exp_corr.png'))
# plt.savefig(os.path.join(fig_path,'sup3/stamp_gene_exp_corr.svg'))
# plt.savefig(os.path.join(fig_path,'sup3/stamp_gene_exp_corr.jpg'))
# Out:
# SignificanceResult(statistic=nan, pvalue=nan)
# (-4.0, 4.0)

# %%
annotated_transcript_editsC= annotate_dataframe_with_transcript_info(transcript_editsC, gtf_file)

# %%
for key in transcript_counts:
    annotated_transcript_editsC = pd.concat([annotated_transcript_editsC, transcript_counts[key]], axis=1)

# %%
annotated_transcript_editsC
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# transcript_id
# ENST00000000233.10        0.015748        0.015748           0.033071
# ENST00000000412.8         0.028152        0.028152           0.022032
# ENST00000000442.11        0.007752        0.002584                NaN
# ENST00000001008.6         0.050100        0.051102           0.046092
# ENST00000002125.9         0.010791        0.001799           0.001799
# ...                            ...             ...                ...
# ENST00000679396.1              NaN             NaN                NaN
# ENST00000582475.1              NaN             NaN                NaN
# ENST00000593233.1              NaN             NaN                NaN
# ENST00000651346.1              NaN             NaN                NaN
# ENST00000477997.5              NaN             NaN                NaN
#
#                     editsC_COCL2_rep2 gene_name transcript_type  \
# transcript_id
# ...

# %%
annotated_transcript_editsC = annotated_transcript_editsC.merge(deseq2_transcript, left_index=True, right_index=True)

# %%
def add_zero_edits_transcript(df):
    for rep in ['1', '2']:
        df.loc[~df[f'231_NT_rep{rep}_count'].isna() & df[f'editsC_NT_rep{rep}'].isna(), f'editsC_NT_rep{rep}'] = 0
        df.loc[~df[f'231_cocl2_rep{rep}_count'].isna()& df[f'editsC_COCL2_rep{rep}'].isna(), f'editsC_COCL2_rep{rep}'] = 0
        
    return df

# %%
add_zero_edits_transcript(annotated_transcript_editsC)
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENST00000000233.10        0.015748        0.015748           0.033071
# ENST00000000412.8         0.028152        0.028152           0.022032
# ENST00000000442.11        0.007752        0.002584                NaN
# ENST00000001008.6         0.050100        0.051102           0.046092
# ENST00000002125.9         0.010791        0.001799           0.001799
# ...                            ...             ...                ...
# ENST00000679396.1              NaN             NaN                NaN
# ENST00000582475.1              NaN             NaN                NaN
# ENST00000593233.1              NaN             NaN                NaN
# ENST00000651346.1              NaN             NaN                NaN
# ENST00000477997.5              NaN             NaN                NaN
#
#                     editsC_COCL2_rep2 gene_name transcript_type  \
# ...

# %%
annotated_transcript_editsC.columns
# Out:
# Index(['editsC_NT_rep1', 'editsC_NT_rep2', 'editsC_COCL2_rep1',
#        'editsC_COCL2_rep2', 'gene_name', 'transcript_type',
#        '231_NT_rep1_count', 'Length', '231_NT_rep1_RPKM',
#        '231_cocl2_rep1_count', 'Length', '231_cocl2_rep1_RPKM',
#        '231_NT_rep2_count', 'Length', '231_NT_rep2_RPKM',
#        '231_cocl2_rep2_count', 'Length', '231_cocl2_rep2_RPKM', 'baseMean',
#        'log2FoldChange', 'lfcSE', 'stat', 'pvalue', 'padj'],
#       dtype='object')

# %%
annotated_transcript_editsC['NT_mean'] = annotated_transcript_editsC.apply(calculate_mean_wt, axis=1)

# %%
annotated_transcript_editsC['COCL2_mean'] = annotated_transcript_editsC.apply(calculate_mean_cocl2, axis=1)

# %%
annotated_transcript_editsC['shortened_transcript_id'] = annotated_transcript_editsC.apply(lambda x: x.name.split('.')[0], axis=1)

# %%
annotated_transcript_editsC['NT_RPKM_mean'] = annotated_transcript_editsC.apply(lambda x: np.mean([x['231_NT_rep1_RPKM'], x['231_NT_rep2_RPKM']]), axis=1)
annotated_transcript_editsC['COCL2_RPKM_mean']= annotated_transcript_editsC.apply(lambda x: np.mean([x['231_cocl2_rep1_RPKM'], x['231_cocl2_rep2_RPKM']]), axis=1)

# %%
annotated_transcript_editsC.dropna().head()
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENST00000000233.10        0.015748        0.015748           0.033071
# ENST00000000412.8         0.028152        0.028152           0.022032
# ENST00000001008.6         0.050100        0.051102           0.046092
# ENST00000002165.11        0.054012        0.094136           0.095679
# ENST00000002596.6         0.001845        0.000615           0.003075
#
#                     editsC_COCL2_rep2 gene_name transcript_type  \
# ENST00000000233.10           0.028346      ARF5  protein_coding
# ENST00000000412.8            0.029376      M6PR  protein_coding
# ENST00000001008.6            0.039078     FKBP4  protein_coding
# ENST00000002165.11           0.098765     FUCA2  protein_coding
# ENST00000002596.6            0.003075    HS3ST1  protein_coding
#
#                     231_NT_rep1_count   Length  231_NT_rep1_RPKM  \
# ENST00000000233.10               66.0   3289.0         14.221750
# ...

# %%
sns.histplot(annotated_transcript_editsC.dropna()['NT_mean'])
sns.histplot(annotated_transcript_editsC.dropna()['COCL2_mean'])
# Out:
# <Axes: xlabel='NT_mean', ylabel='Count'>

# %%
sns.scatterplot(data=annotated_transcript_editsC.dropna(), x='NT_mean', y='COCL2_mean', alpha=0.5, linewidth=0)
# Out:
# <Axes: xlabel='NT_mean', ylabel='COCL2_mean'>

# %%
annotated_transcript_editsC_copy = annotated_transcript_editsC.dropna().copy()

# %%
annotated_transcript_editsC_copy['edit_FC'] = annotated_transcript_editsC_copy['COCL2_mean']/annotated_transcript_editsC_copy['NT_mean']

# %%
annotated_transcript_editsC_copy = annotated_transcript_editsC_copy[np.abs(annotated_transcript_editsC_copy['edit_FC']) != float('inf')]

# %%
annotated_transcript_editsC_copy['edit_logFC'] = np.log2(annotated_transcript_editsC_copy['edit_FC'])
# Out:
# /tscc/projects/ps-yeolab4/software/miniconda_tscc2/envs/python3essential-1.99.0/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
annotated_transcript_editsC_copy = annotated_transcript_editsC_copy[np.abs(annotated_transcript_editsC_copy['edit_logFC']) != float('inf')]

# %%
annotated_transcript_editsC_copy['ttest_pval'] = annotated_transcript_editsC_copy.apply(lambda x: stats.ttest_ind([x['editsC_NT_rep1'], x['editsC_NT_rep1']], [x['editsC_COCL2_rep1'], x['editsC_COCL2_rep2']])[1], axis=1)
# Out:
# /tscc/projects/ps-yeolab4/software/miniconda_tscc2/envs/python3essential-1.99.0/lib/python3.9/site-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
annotated_transcript_editsC_copy = annotated_transcript_editsC_copy.sort_values(by='edit_logFC', ascending=False)

# %%
annotated_transcript_editsC_copy[annotated_transcript_editsC_copy['gene_name']=='PCMT1']
# Out:
#                    editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENST00000367378.6        0.015528        0.021739           0.068323
# ENST00000367384.7        0.040816        0.020408           0.034014
# ENST00000649295.1        0.004535        0.004535           0.004535
#
#                    editsC_COCL2_rep2 gene_name transcript_type  \
# ENST00000367378.6           0.059006     PCMT1  protein_coding
# ENST00000367384.7           0.034014     PCMT1  protein_coding
# ENST00000649295.1           0.004535     PCMT1  protein_coding
#
#                    231_NT_rep1_count   Length  231_NT_rep1_RPKM  \
# ENST00000367378.6               53.0  53086.0          0.707569
# ENST00000367384.7              157.0  61977.0          1.795321
# ENST00000649295.1               35.0  61725.0          0.401865
#
#                    231_cocl2_rep1_count  ...    pvalue      padj   NT_mean  \
# ENST00000367378.6                 154.0  ...  0.000059  0.001463  0.018634
# ...

# %%
annotated_transcript_editsC_copy.head()
# Out:
#                    editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENST00000370406.8        0.000000        0.002066           0.012397
# ENST00000392508.2        0.000000        0.001883           0.003766
# ENST00000611119.4        0.000000        0.000746           0.005224
# ENST00000442528.2        0.001576        0.000788           0.009456
# ENST00000222402.8        0.000000        0.000879           0.004394
#
#                    editsC_COCL2_rep2 gene_name transcript_type  \
# ENST00000370406.8           0.008264     EOLA2  protein_coding
# ENST00000392508.2           0.013183    DYNLL1  protein_coding
# ENST00000611119.4           0.001493  TMEM185A  protein_coding
# ENST00000442528.2           0.010244   SLC35C1  protein_coding
# ENST00000222402.8           0.002636    UBE2D4  protein_coding
#
#                    231_NT_rep1_count   Length  231_NT_rep1_RPKM  \
# ENST00000370406.8               26.0   6294.0          2.927653
# ...

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.set_style('white')
sns.scatterplot(x=annotated_transcript_editsC_copy['log2FoldChange'], y=-np.log(annotated_transcript_editsC_copy['padj']), color='lightgrey',linewidth=0, alpha=0.5)
sns.scatterplot(x=annotated_transcript_editsC_copy[annotated_transcript_editsC_copy['edit_logFC']>1.0]['log2FoldChange'], y=-np.log10(annotated_transcript_editsC_copy[annotated_transcript_editsC_copy['edit_logFC']>1.0]['padj']), color='orange',linewidth=0, alpha=0.5)
sns.scatterplot(x=annotated_transcript_editsC_copy[annotated_transcript_editsC_copy['edit_logFC']<-1.0]['log2FoldChange'], y=-np.log10(annotated_transcript_editsC_copy[annotated_transcript_editsC_copy['edit_logFC']<-1.0]['padj']), color='purple',linewidth=0, alpha=0.5)
plt.axvline(1.0, color='darkgrey', linestyle='--')
plt.axvline(-1., color='darkgrey', linestyle='--')
plt.axhline(-np.log10(0.05), color='darkgrey', linestyle='--')

# %%
# down transcr, down transl
annotated_transcript_editsC_copy[(annotated_transcript_editsC_copy['edit_logFC']<=-1.0) & (annotated_transcript_editsC_copy['log2FoldChange']<-1.0) & (annotated_transcript_editsC_copy['padj']<=0.05)].shape[0]
# Out:
# 173

# %%
# no transcr, down transl
annotated_transcript_editsC_copy[(annotated_transcript_editsC_copy['edit_logFC']<-1.0) & (np.abs(annotated_transcript_editsC_copy['log2FoldChange'])<1.0) & (annotated_transcript_editsC_copy['padj']>0.05)].shape[0]
# Out:
# 275

# %%
# up transcr, up transl
annotated_transcript_editsC_copy[(annotated_transcript_editsC_copy['edit_logFC']>=1.0) & (annotated_transcript_editsC_copy['log2FoldChange']>=1.0) & (annotated_transcript_editsC_copy['padj']<=0.05)].shape[0]
# Out:
# 191

# %%
# no transcr, up transl
annotated_transcript_editsC_copy[(annotated_transcript_editsC_copy['edit_logFC']>=1.0) & (np.abs(annotated_transcript_editsC_copy['log2FoldChange'])<1.0) & (annotated_transcript_editsC_copy['padj']>0.05)].shape[0]
# Out:
# 320

# %%
# down transcr, down transl
annotated_transcript_editsC_copy[(annotated_transcript_editsC_copy['edit_logFC']>=1.0) & (annotated_transcript_editsC_copy['log2FoldChange']<-1.0) & (annotated_transcript_editsC_copy['padj']<=0.05)].shape[0]
# Out:
# 0

# %%
sns.set(rc={'figure.figsize':(4,4)})
sns.set_style('white')
sns.scatterplot(data=annotated_transcript_editsC_copy, x='log2FoldChange', y='edit_logFC', alpha=0.5, linewidth=0, color='#7E1F86')
print(stats.spearmanr(annotated_transcript_editsC_copy['log2FoldChange'], annotated_transcript_editsC_copy['edit_logFC']))
plt.xlim(-2, 2)
plt.ylim(-4,4)
# plt.savefig(os.path.join(fig_path,'sup3/stamp_exp_corr.png'))
# plt.savefig(os.path.join(fig_path,'sup3/stamp_exp_corr.svg'))
# plt.savefig(os.path.join(fig_path,'sup3/stamp_exp_corr.jpg'))
# Out:
# SignificanceResult(statistic=0.8269523444205541, pvalue=0.0)
# (-4.0, 4.0)

# %%
up_only_translation = annotated_transcript_editsC_copy[(np.abs(annotated_transcript_editsC_copy['log2FoldChange']<1)) & (annotated_transcript_editsC_copy['padj']>0.05) & (annotated_transcript_editsC_copy['edit_logFC'] >1)]

# %%
down_only_translation = annotated_transcript_editsC_copy[(np.abs(annotated_transcript_editsC_copy['log2FoldChange']<1)) & (annotated_transcript_editsC_copy['padj']>0.05) & (annotated_transcript_editsC_copy['edit_logFC'] <-1)]

# %%
up_transcription_translation = annotated_transcript_editsC_copy[(annotated_transcript_editsC_copy['log2FoldChange']>1) & (annotated_transcript_editsC_copy['padj']<=0.05) & (annotated_transcript_editsC_copy['edit_logFC'] >1)]

# %%
down_transcription_translation = annotated_transcript_editsC_copy[(annotated_transcript_editsC_copy['log2FoldChange']<-1) & (annotated_transcript_editsC_copy['padj']<=0.05) & (annotated_transcript_editsC_copy['edit_logFC'] <-1)]

# %%
#up_only_translation.to_csv('231_NT_COCL2_transcript_up_only_translation_jan2024.txt', sep='\t')

# %%
#down_only_translation.to_csv('231_NT_COCL2_transcript_down_only_translation_jan2024.txt', sep='\t')

# %%
#up_transcription_translation.to_csv('231_NT_COCL2_transcript_up_transcription_translation_jan2024.txt', sep='\t')

# %%
#down_transcription_translation.to_csv('231_NT_COCL2_transcript_down_transcription_translation_jan2024.txt', sep='\t')

# %%
five_UTR_hre_seq_annotation = pd.read_csv('5UTR_gtf_seq_hre_annotation.txt', sep='\t')

# %%
hre_transcripts = five_UTR_hre_seq_annotation[five_UTR_hre_seq_annotation['five_hre_motif']==True]['transcript_id'].to_list()

# %%
fig, axes = plt.subplots(1, 2, figsize=(6, 3), sharey=True)

five_hre_present_nt = annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(hre_transcripts)][['NT_mean']]
five_hre_present_nt['condition'] = 'NT'
five_hre_present_nt = five_hre_present_nt.rename(columns={'NT_mean':'mean'})
five_hre_present_cocl2 = annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(hre_transcripts)][['COCL2_mean']]
five_hre_present_cocl2['condition'] = 'COCL2'
five_hre_present_cocl2 = five_hre_present_cocl2.rename(columns={'COCL2_mean':'mean'})
print(stats.ranksums(five_hre_present_nt['mean'], five_hre_present_cocl2['mean']))


sns.boxplot(data=pd.concat([five_hre_present_nt, five_hre_present_cocl2]), x='condition',y='mean', hue='condition', ax=axes[0], palette=custom_palette)
#axes[0].text('NT', five_hre_present_transcripts.loc['ENST00000379341.9', 'NT_mean'], 'PRDX4')
#axes[0].text('COCL2', five_hre_present_transcripts.loc['ENST00000379341.9', 'COCL2_mean'], 'PRDX4')
axes[0].text('NT', five_hre_present_transcripts.loc['ENST00000215754.8', 'NT_mean'], 'MIF-201')
axes[0].text('COCL2', five_hre_present_transcripts.loc['ENST00000215754.8', 'COCL2_mean'], 'MIF-201')
# plt.savefig(os.path.join(fig_path,'fig5/five_hre.png'))
# plt.savefig(os.path.join(fig_path,'fig5/five_hre.svg'))
# plt.savefig(os.path.join(fig_path,'fig5/five_hre.jpg'))
# Out:
# RanksumsResult(statistic=-0.19571560589672693, pvalue=0.844832768897147)
# /tmp/ipykernel_3989180/1017313294.py:12: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.boxplot(data=pd.concat([five_hre_present_nt, five_hre_present_cocl2]), x='condition',y='mean', hue='condition', ax=axes[0], palette=custom_palette)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[254], line 15
#      12 sns.boxplot(data=pd.concat([five_hre_present_nt, five_hre_present_cocl2]), x='condition',y='mean', hue='condition', ax=axes[0], palette=custom_palette)
#      13 #axes[0].text('NT', five_hre_present_transcripts.loc['ENST00000379341.9', 'NT_mean'], 'PRDX4')
#      14 #axes[0].text('COCL2', five_hre_present_transcripts.loc['ENST00000379341.9', 'COCL2_mean'], 'PRDX4')
# ...

# %%
five_hre_present_transcripts  =  annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(hre_transcripts)]

# %%
five_hre_present_transcripts['delta_EditsC'] = five_hre_present_transcripts.apply(lambda x: x['COCL2_mean'] - x['NT_mean'], axis=1)
# Out:
# /tmp/ipykernel_3989180/3869707784.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   five_hre_present_transcripts['delta_EditsC'] = five_hre_present_transcripts.apply(lambda x: x['COCL2_mean'] - x['NT_mean'], axis=1)

# %%
five_hre_present_transcripts[(five_hre_present_transcripts['ttest_pval'] <= 0.05) & (five_hre_present_transcripts['edit_logFC'] >=1)].sort_values(by='delta_EditsC', ascending=False).head(10)
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENST00000379341.9         0.051282        0.098901           0.175824
# ENST00000215754.8         0.030651        0.061303           0.126437
# ENST00000248437.9         0.042614        0.072443           0.112216
# ENST00000221801.8         0.027027        0.040541           0.094595
# ENST00000262890.8         0.024213        0.036320           0.094431
# ENST00000367378.6         0.015528        0.021739           0.068323
# ENST00000216185.7         0.019178        0.030137           0.063014
# ENST00000270517.12        0.024510        0.031046           0.062092
# ENST00000319285.5         0.028796        0.023560           0.068063
# ENST00000588234.6         0.009524        0.003175           0.041270
#
#                     editsC_COCL2_rep2 gene_name transcript_type  \
# ENST00000379341.9            0.183150     PRDX4  protein_coding
# ENST00000215754.8            0.122605       MIF  protein_coding
# ...

# %%
five_UTR_seq_annotation = pd.read_csv('5UTR_gtf_seq_annotation.txt', sep='\t')

# %%
five_UTR_seq_top_present = set(five_UTR_seq_annotation[five_UTR_seq_annotation['five_top_motif']==True]['transcript_id'].tolist())

# %%
five_UTR_seq_top_absent = set(five_UTR_seq_annotation[five_UTR_seq_annotation['five_top_motif']==False]['transcript_id'].tolist())

# %% [markdown]
# 5'TOP mRNAs, which often encode for components of the translational machinery like ribosomal proteins and elongation factors, are selectively regulated by mTORC1. Under conditions where mTORC1 is active, such as in the presence of sufficient nutrients and growth signals, there is an increase in the translation of 5'TOP mRNAs. Conversely, when mTORC1 is inhibited or inactive, as in conditions of nutrient deprivation or stress, the translation of these mRNAs is downregulated.(chatGPT)

# %%
fig, axes = plt.subplots(1, 2, figsize=(6, 3), sharey=True)

five_top_present_nt = annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(five_UTR_seq_top_present)][['NT_mean']]
five_top_present_nt['condition'] = 'NT'
five_top_present_nt = five_top_present_nt.rename(columns={'NT_mean':'mean'})
five_top_present_cocl2 = annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(five_UTR_seq_top_present)][['COCL2_mean']]
five_top_present_cocl2['condition'] = 'COCL2'
five_top_present_cocl2 = five_top_present_cocl2.rename(columns={'COCL2_mean':'mean'})
print(stats.ranksums(five_top_present_nt['mean'], five_top_present_cocl2['mean']))

five_top_absent_nt = annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(five_UTR_seq_top_absent)][['NT_mean']]
five_top_absent_nt['condition'] = 'NT'
five_top_absent_nt = five_top_absent_nt.rename(columns={'NT_mean':'mean'})
five_top_absent_cocl2 = annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(five_UTR_seq_top_absent)][['COCL2_mean']]
five_top_absent_cocl2['condition'] = 'COCL2'
five_top_absent_cocl2 = five_top_absent_cocl2.rename(columns={'COCL2_mean':'mean'})
print(stats.ranksums(five_top_absent_nt['mean'], five_top_absent_cocl2['mean']))

sns.boxplot(data=pd.concat([five_top_present_nt, five_top_present_cocl2]), x='condition',y='mean', hue='condition', ax=axes[0], palette=custom_palette)
sns.boxplot(data=pd.concat([five_top_absent_nt, five_top_absent_cocl2]), x='condition', y='mean', hue='condition', ax=axes[1], palette=custom_palette)
axes[0].text('NT', five_top_present_transcripts.loc['ENST00000371646.10', 'NT_mean'], 'HSP90AB1-203')
axes[0].text('COCL2', five_top_present_transcripts.loc['ENST00000371646.10', 'COCL2_mean'], 'HSP90AB1-203')
# plt.savefig(os.path.join(fig_path,'sup3/five_top.png'))
# plt.savefig(os.path.join(fig_path,'sup3/five_top.svg'))
# plt.savefig(os.path.join(fig_path,'sup3/five_top.jpg'))
# Out:
# RanksumsResult(statistic=-1.3919325623045846, pvalue=0.16394282026095408)
# RanksumsResult(statistic=-1.5358972288154316, pvalue=0.12456358792206713)
# /tmp/ipykernel_3989180/4163696726.py:19: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.boxplot(data=pd.concat([five_top_present_nt, five_top_present_cocl2]), x='condition',y='mean', hue='condition', ax=axes[0], palette=custom_palette)
# /tmp/ipykernel_3989180/4163696726.py:20: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.boxplot(data=pd.concat([five_top_absent_nt, five_top_absent_cocl2]), x='condition', y='mean', hue='condition', ax=axes[1], palette=custom_palette)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[261], line 21
# ...

# %%
five_top_present_transcripts= annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(five_UTR_seq_top_present)]

# %%
five_top_present_transcripts['delta_EditsC'] = five_top_present_transcripts.apply(lambda x: x['COCL2_mean'] - x['NT_mean'], axis=1)
# Out:
# /tmp/ipykernel_3989180/114568480.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   five_top_present_transcripts['delta_EditsC'] = five_top_present_transcripts.apply(lambda x: x['COCL2_mean'] - x['NT_mean'], axis=1)

# %%
five_top_present_transcripts.sort_values(by='delta_EditsC').head(10)#['gene_name'].tolist()
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENST00000371646.10        0.254937        0.170557           0.100539
# ENST00000300738.10        0.160584        0.127007           0.078832
# ENST00000309311.7         0.158082        0.150089           0.074600
# ENST00000302763.12        0.138122        0.099448           0.069455
# ENST00000394440.8         0.153704        0.137037           0.088889
# ENST00000373585.8         0.119835        0.064050           0.055785
# ENST00000517309.6         0.079215        0.058866           0.035610
# ENST00000354725.8         0.129707        0.082845           0.074477
# ENST00000265174.5         0.065469        0.065469           0.021823
# ENST00000238081.8         0.098720        0.069470           0.043876
#
#                     editsC_COCL2_rep2 gene_name transcript_type  \
# ENST00000371646.10           0.136445  HSP90AB1  protein_coding
# ENST00000300738.10           0.061314      RRM1  protein_coding
# ...

# %%
#annotated_transcript_editsC_copy.to_csv('annotated_transcript_editsC_copy_jan2024.txt', sep='\t')

# %%
annotated_transcript_editsC_copy[(np.abs(annotated_transcript_editsC_copy['log2FoldChange']>1)) & (annotated_transcript_editsC_copy['padj']<=0.05) & (np.abs(annotated_transcript_editsC_copy['edit_logFC']) >1)]['gene_name'].value_counts().head(15)
# Out:
# gene_name
# ADRM1       2
# MRPL24      2
# C7orf50     2
# CENPX       2
# WDR54       1
# TRAPPC3     1
# NDUFS7      1
# PMF1        1
# CREB3       1
# RPL10       1
# EMC3        1
# TPGS1       1
# ABT1        1
# SLC25A39    1
# APRT        1
# Name: count, dtype: int64

# %%
annotated_transcript_editsC_copy[(np.abs(annotated_transcript_editsC_copy['log2FoldChange']<1)) & (annotated_transcript_editsC_copy['padj']>0.05) & (np.abs(annotated_transcript_editsC_copy['edit_logFC']) >1)]['gene_name'].value_counts().head(15)
# Out:
# gene_name
# FHL2        3
# TMEM185A    2
# ISOC2       2
# MYEOV       2
# NET1        2
# RNH1        2
# DHRSX       2
# UBA52       2
# AP2A2       2
# NONO        2
# METTL5      2
# TSPAN4      2
# PTPN11      1
# KANSL2      1
# TTC27       1
# Name: count, dtype: int64

# %%
annotated_transcript_editsC_copy[annotated_transcript_editsC_copy['gene_name']=='FHL2']
# Out:
#                    editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENST00000408995.5        0.004304        0.000000           0.005739
# ENST00000530340.6        0.000681        0.002723           0.005446
# ENST00000393353.7        0.005022        0.006456           0.011478
#
#                    editsC_COCL2_rep2 gene_name transcript_type  \
# ENST00000408995.5           0.008608      FHL2  protein_coding
# ENST00000530340.6           0.002723      FHL2  protein_coding
# ENST00000393353.7           0.012912      FHL2  protein_coding
#
#                    231_NT_rep1_count   Length  231_NT_rep1_RPKM  \
# ENST00000408995.5               33.0  38189.0          0.612419
# ENST00000530340.6               27.0  38225.0          0.500598
# ENST00000393353.7               81.0  38225.0          1.501795
#
#                    231_cocl2_rep1_count  ...    pvalue      padj   NT_mean  \
# ENST00000408995.5                  60.0  ...  0.029982  0.086405  0.002152
# ...

# %%
annotated_transcript_editsC_copy[annotated_transcript_editsC_copy['gene_name'].str.contains('APP')]
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENST00000250454.8         0.002146        0.015021           0.040773
# ENST00000303731.9         0.024793        0.027548           0.066116
# ENST00000373166.8         0.006904        0.006904           0.018412
# ENST00000596148.3         0.006702        0.010054           0.019437
# ENST00000301021.7         0.001695        0.011864           0.014407
# ENST00000533632.6         0.014317        0.005507           0.020925
# ENST00000346798.8         0.071245        0.030043           0.054077
# ENST00000324266.10        0.029891        0.031703           0.025362
# ENST00000357903.7         0.093023        0.054562           0.037567
#
#                     editsC_COCL2_rep2 gene_name transcript_type  \
# ENST00000250454.8            0.038627      EAPP  protein_coding
# ENST00000303731.9            0.060606   TRAPPC1  protein_coding
# ENST00000373166.8            0.013809   TRAPPC3  protein_coding
# ...

# %%
transcripts_per_gene_df = pd.DataFrame(annotated_transcript_editsC_copy.dropna()['gene_name'].value_counts())

# %%
multiple_genes_list = transcripts_per_gene_df[transcripts_per_gene_df['count']>1].index.tolist()

# %%
len(multiple_genes_list)
# Out:
# 490

# %%
annotated_transcript_editsC_copy.dropna().shape[0]
# Out:
# 5150

# %%
annotated_transcript_editsC_copy[annotated_transcript_editsC_copy['transcript_type']=='nonsense_mediated_decay'].dropna().head()
# Out:
#                    editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENST00000608166.2        0.001921        0.000000           0.008646
# ENST00000447927.6        0.000000        0.001984           0.007937
# ENST00000378331.5        0.000000        0.001570           0.006279
# ENST00000415762.6        0.000000        0.003344           0.008361
# ENST00000586527.1        0.000000        0.005525           0.005525
#
#                    editsC_COCL2_rep2 gene_name          transcript_type  \
# ENST00000608166.2           0.005764     GLRX2  nonsense_mediated_decay
# ENST00000447927.6           0.005952      EIF6  nonsense_mediated_decay
# ENST00000378331.5           0.000000   SUV39H2  nonsense_mediated_decay
# ENST00000415762.6           0.003344      YDJC  nonsense_mediated_decay
# ENST00000586527.1           0.011050       UNK  nonsense_mediated_decay
#
#                    231_NT_rep1_count   Length  231_NT_rep1_RPKM  \
# ...

# %%
annotated_transcript_editsC.dropna()['transcript_type'].value_counts()
# Out:
# transcript_type
# protein_coding             5185
# nonsense_mediated_decay      39
# non_stop_decay                1
# Name: count, dtype: int64

# %%
multiple_transcript_genes_df = annotated_transcript_editsC_copy[annotated_transcript_editsC_copy['gene_name'].isin(multiple_genes_list)].dropna()

# %%
multiple_transcript_genes_df.sort_values(by='gene_name')#['gene_name'].value_counts()
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENST00000444053.5         0.010549        0.018987           0.017932
# ENST00000248450.9         0.027426        0.026371           0.044304
# ENST00000642319.1         0.002322        0.004063           0.004643
# ENST00000367595.4         0.022727        0.016529           0.033058
# ENST00000457657.5         0.005376        0.006452           0.008602
# ...                            ...             ...                ...
# ENST00000394670.9         0.009087        0.006816           0.004165
# ENST00000254821.10        0.010135        0.010135           0.011261
# ENST00000370920.8         0.005631        0.007883           0.005631
# ENST00000373944.8         0.034146        0.035772           0.053659
# ENST00000395405.5         0.004878        0.006504           0.001626
#
#                     editsC_COCL2_rep2 gene_name transcript_type  \
# ...

# %%
import itertools

# %%
list(itertools.combinations(multiple_transcript_genes_df[multiple_transcript_genes_df['gene_name']=='RNH1'].index.tolist(), 2))
# Out:
# [('ENST00000533410.5', 'ENST00000354420.7'),
#  ('ENST00000533410.5', 'ENST00000397615.6'),
#  ('ENST00000533410.5', 'ENST00000397604.7'),
#  ('ENST00000533410.5', 'ENST00000356187.9'),
#  ('ENST00000354420.7', 'ENST00000397615.6'),
#  ('ENST00000354420.7', 'ENST00000397604.7'),
#  ('ENST00000354420.7', 'ENST00000356187.9'),
#  ('ENST00000397615.6', 'ENST00000397604.7'),
#  ('ENST00000397615.6', 'ENST00000356187.9'),
#  ('ENST00000397604.7', 'ENST00000356187.9')]

# %%
multiple_transcript_genes_df[multiple_transcript_genes_df.index=='ENST00000533410.5'][['editsC_NT_rep1', 'editsC_NT_rep2', 'editsC_COCL2_rep1', 'editsC_COCL2_rep2']]
# Out:
#                    editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENST00000533410.5        0.000969        0.001453           0.004358
#
#                    editsC_COCL2_rep2
# ENST00000533410.5           0.003874

# %%
tfs_df = pd.DataFrame()
for gene in set(multiple_transcript_genes_df['gene_name'].tolist()):
    tmp_df = multiple_transcript_genes_df[multiple_transcript_genes_df.gene_name==gene]
    all_ts = list(itertools.combinations(tmp_df.index.tolist(), 2))
    count = 0
    for pair in all_ts:
        t1_df = tmp_df[tmp_df.index==pair[0]][['gene_name', 'editsC_NT_rep1', 'editsC_NT_rep2', 'editsC_COCL2_rep1', 'editsC_COCL2_rep2', 'NT_mean', 'COCL2_mean', 'edit_FC', 'edit_logFC', 'log2FoldChange', 'padj']]
        t2_df = tmp_df[tmp_df.index==pair[1]][['gene_name','editsC_NT_rep1', 'editsC_NT_rep2', 'editsC_COCL2_rep1', 'editsC_COCL2_rep2', 'NT_mean', 'COCL2_mean','edit_FC', 'edit_logFC', 'log2FoldChange', 'padj']]
        pair_df = t1_df.reset_index().merge(t2_df.reset_index(), on='gene_name', suffixes=['_A', '_B'])
        #pair_df.loc[pair_df.index[0], 'gene_name'] = f"{gene}_{count}"
        pair_df['label'] = f"{gene}_{count}"
        tfs_df = pd.concat([tfs_df, pair_df])
        count +=1

# %%
tfs_df[tfs_df['gene_name']=='HIF1A']
# Out:
# Empty DataFrame
# Columns: [index_A, gene_name, editsC_NT_rep1_A, editsC_NT_rep2_A, editsC_COCL2_rep1_A, editsC_COCL2_rep2_A, NT_mean_A, COCL2_mean_A, edit_FC_A, edit_logFC_A, log2FoldChange_A, padj_A, index_B, editsC_NT_rep1_B, editsC_NT_rep2_B, editsC_COCL2_rep1_B, editsC_COCL2_rep2_B, NT_mean_B, COCL2_mean_B, edit_FC_B, edit_logFC_B, log2FoldChange_B, padj_B, label]
# Index: []
#
# [0 rows x 24 columns]

# %%
tfs_df_toplot = tfs_df.sort_values('gene_name').set_index('label')[['editsC_NT_rep1_A', 'editsC_NT_rep2_A', 'editsC_COCL2_rep1_A', 'editsC_COCL2_rep2_A','editsC_NT_rep1_B', 'editsC_NT_rep2_B', 'editsC_COCL2_rep1_B', 'editsC_COCL2_rep2_B']]

# %%
sns.clustermap(tfs_df_toplot, col_cluster = False, cmap='mako_r')
# plt.savefig(os.path.join(fig_path,'fig4/multiple_transcripts.png'))
# plt.savefig(os.path.join(fig_path,'fig4/multiple_transcripts.svg'))
# plt.savefig(os.path.join(fig_path,'fig4/multiple_transcripts.jpg'))

# %%
tfs_df['COCL2_dif'] = tfs_df['COCL2_mean_A'] - tfs_df['COCL2_mean_B']

# %%
tfs_df['NT_dif'] = tfs_df['NT_mean_A'] - tfs_df['NT_mean_B']

# %%
tfs_df['dif_FC'] = abs(tfs_df['COCL2_dif']/tfs_df['NT_dif'])

# %%
tfs_df[tfs_df['gene_name'].str.contains("HSP")]

# %%
tfs_df[tfs_df['dif_FC'] !=float('inf')].sort_values(by='dif_FC', ascending=False)

# %%
#pd.read_csv('all_sample_counts_matrix_transcript-Copy1.csv').to_csv('all_sample_counts_matrix_transcript-FLAIRdiffsplice.tsv', sep='\t', index=False)

# %%
diffsplice_dir = '~/projects/STAMP/stamp_v3_pipeline/notebooks/231_data/diffsplice/flair_diffsplice_out'

# %%
event_dict = {'alt3':{}, 'alt5':{}, 'es':{}, 'ir':{}, }
for event_type in event_dict:
    for row, index in pd.read_csv(os.path.join(diffsplice_dir, f'diffsplice.{event_type}.events.quant.tsv'), sep='\t').iterrows():
        if index['feature_id'] not in event_dict[event_type]:
                event_dict[event_type][index['feature_id']] = []
        for id in index['isoform_ids'].split(','):
            event_dict[event_type][index['feature_id']].append(id)

# %%
event_as_df_dict = {}
for event_type in event_dict:
    event_as_df = pd.read_csv(f'/tscc/nfs/home/pjaganna1/projects/STAMP/stamp_v3_pipeline/notebooks/231_data/diffsplice/flair_diffsplice_out_drim/drimseq_{event_type}_NT_v_COCL2.tsv', sep='\t')
    event_as_df['isoforms'] = event_as_df.feature_id.map(event_dict[event_type])
    #event_as_df['gene_name'] = event_as_df.isoforms.map(gtf_transcript_to_gene_dict)
    event_as_df_dict[event_type] = event_as_df

# %%
event_as_dict = {}
event_count_dict = {}
for event_type in event_dict:
    exclusion = [x for xs in event_as_df_dict[event_type][event_as_df_dict[event_type]['feature_id'].str.contains('exclusion')]['isoforms'].tolist() for x in xs]
    inclusion = [x for xs in event_as_df_dict[event_type][event_as_df_dict[event_type]['feature_id'].str.contains('inclusion')]['isoforms'].tolist() for x in xs]

    exclusion_df = annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(exclusion)]
    #exclusion_df[event_type] = 'exclusion'
    inclusion_df = annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(inclusion)]
    #inclusion_df[event_type] = 'inclusion'

    if exclusion_df.shape[0] > 0 and inclusion_df.shape[0] > 0:

        fig, axes = plt.subplots(1, len(list(exclusion_df.index)), sharey=True, figsize=(5*len(list(exclusion_df.index)),5))
        count = 0
        excl_gene_name = []
        for t in list(exclusion_df.index):
            sns.barplot(pd.DataFrame([['NT', exclusion_df.loc[t,'editsC_NT_rep1'], exclusion_df.loc[t,'editsC_NT_rep2']], ['COCL2', exclusion_df.loc[t,'editsC_COCL2_rep1'], exclusion_df.loc[t,'editsC_COCL2_rep2']]]).set_index(0).T, ax=axes[count])
            sns.stripplot(pd.DataFrame([['NT', exclusion_df.loc[t,'editsC_NT_rep1'], exclusion_df.loc[t,'editsC_NT_rep2']], ['COCL2', exclusion_df.loc[t,'editsC_COCL2_rep1'], exclusion_df.loc[t,'editsC_COCL2_rep2']]]).set_index(0).T, ax=axes[count])
            axes[count].set_title(f'{t}_{exclusion_df.loc[t,"gene_name"]}_{event_type}_exclusion')
            excl_gene_name.append(exclusion_df.loc[t,"gene_name"])
            count+=1
        plt.show()
    
        fig, axes = plt.subplots(1, len(list(inclusion_df.index)), sharey=True, figsize=(5*len(list(inclusion_df.index)),5))
        count = 0
        incl_gene_name = []
        for t in list(inclusion_df.index):
            sns.barplot(pd.DataFrame([['NT', inclusion_df.loc[t,'editsC_NT_rep1'], inclusion_df.loc[t,'editsC_NT_rep2']], ['COCL2', inclusion_df.loc[t,'editsC_COCL2_rep1'], inclusion_df.loc[t,'editsC_COCL2_rep2']]]).set_index(0).T, ax=axes[count])
            sns.stripplot(pd.DataFrame([['NT', inclusion_df.loc[t,'editsC_NT_rep1'], inclusion_df.loc[t,'editsC_NT_rep2']], ['COCL2', inclusion_df.loc[t,'editsC_COCL2_rep1'], inclusion_df.loc[t,'editsC_COCL2_rep2']]]).set_index(0).T, ax=axes[count])
            axes[count].set_title(f'{t}_{inclusion_df.loc[t,"gene_name"]}_{event_type}_inclusion')
            incl_gene_name.append(inclusion_df.loc[t,"gene_name"])
            count +=1
        plt.show()

# %%
annotated_transcript_editsC_copy

# %%
isoswitch_r = pd.read_csv('diffsplice/IsoSwitch_AS_out.txt', sep='\t').set_index('isoform_id')

# %%
isoswitch_editsC_merge = annotated_transcript_editsC_copy.merge(isoswitch_r, right_index=True, left_index=True)

# %%
isoswitch_editsC_merge.columns
# Out:
# Index(['editsC_NT_rep1', 'editsC_NT_rep2', 'editsC_COCL2_rep1',
#        'editsC_COCL2_rep2', 'gene_name_x', 'transcript_type',
#        '231_NT_rep1_count', 'Length', '231_NT_rep1_RPKM',
#        '231_cocl2_rep1_count', 'Length', '231_cocl2_rep1_RPKM',
#        '231_NT_rep2_count', 'Length', '231_NT_rep2_RPKM',
#        '231_cocl2_rep2_count', 'Length', '231_cocl2_rep2_RPKM', 'baseMean',
#        'log2FoldChange', 'lfcSE', 'stat', 'pvalue', 'padj', 'NT_mean',
#        'COCL2_mean', 'shortened_transcript_id', 'NT_RPKM_mean',
#        'COCL2_RPKM_mean', 'edit_FC', 'edit_logFC', 'ttest_pval', 'iso_ref',
#        'gene_ref', 'gene_id', 'condition_1', 'condition_2', 'gene_name_y',
#        'gene_biotype', 'iso_biotype', 'gene_overall_mean', 'gene_value_1',
#        'gene_value_2', 'gene_stderr_1', 'gene_stderr_2',
#        'gene_log2_fold_change', 'gene_q_value', 'iso_overall_mean',
#        'iso_value_1', 'iso_value_2', 'iso_stderr_1', 'iso_stderr_2',
# ...

# %%
isoswitch_editsC_merge.columns
# Out:
# Index(['editsC_NT_rep1', 'editsC_NT_rep2', 'editsC_COCL2_rep1',
#        'editsC_COCL2_rep2', 'gene_name_x', 'transcript_type',
#        '231_NT_rep1_count', 'Length', '231_NT_rep1_RPKM',
#        '231_cocl2_rep1_count', 'Length', '231_cocl2_rep1_RPKM',
#        '231_NT_rep2_count', 'Length', '231_NT_rep2_RPKM',
#        '231_cocl2_rep2_count', 'Length', '231_cocl2_rep2_RPKM', 'baseMean',
#        'log2FoldChange', 'lfcSE', 'stat', 'pvalue', 'padj', 'NT_mean',
#        'COCL2_mean', 'shortened_transcript_id', 'NT_RPKM_mean',
#        'COCL2_RPKM_mean', 'edit_FC', 'edit_logFC', 'ttest_pval', 'iso_ref',
#        'gene_ref', 'gene_id', 'condition_1', 'condition_2', 'gene_name_y',
#        'gene_biotype', 'iso_biotype', 'gene_overall_mean', 'gene_value_1',
#        'gene_value_2', 'gene_stderr_1', 'gene_stderr_2',
#        'gene_log2_fold_change', 'gene_q_value', 'iso_overall_mean',
#        'iso_value_1', 'iso_value_2', 'iso_stderr_1', 'iso_stderr_2',
# ...

# %%
lut1 = dict(zip(isoswitch_editsC_merge.sort_values(by='dIF', ascending=False)['switchConsequencesGene'].unique(), ['#ED2323','#60FD00']))
row_colors1 = isoswitch_editsC_merge.sort_values(by='dIF', ascending=False)['switchConsequencesGene'].map(lut1)

# %%
ax=sns.heatmap(isoswitch_editsC_merge.sort_values(by='dIF', ascending=False)[['dIF','NT_mean', 'COCL2_mean']], cmap='PuOr')#,row_colors=row_colors1, col_cluster=False)#,'switchConsequencesGene']]
ax.tick_params(axis='y', which='major', pad=20, length=0) # extra padding to leave room for the row colors
#ax.set_yticklabels(data['group'], rotation=0) # optionally use the groups as the tick labels
for i, color in enumerate(row_colors1):
    ax.add_patch(plt.Rectangle(xy=(-0.05, i), width=0.05, height=1, color=color, lw=0,
                               transform=ax.get_yaxis_transform(), clip_on=False))
#plt.tight_layout()
plt.show()
sns.heatmap(isoswitch_editsC_merge.sort_values(by='dIF', ascending=False)[['NT_mean', 'COCL2_mean']], cmap='Greys')#,row_colors=row_colors1, col_cluster=False)#,'switchConsequencesGene']]
# Out:
# <Axes: >

# %% [markdown]
# PCMT1 is highly expressed and prognostic in breast cancer https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9078795/

# %%
isoswitch_editsC_merge_copy = isoswitch_editsC_merge.copy()

# %%
isoswitch_editsC_merge_copy['hsp_annot'] = isoswitch_editsC_merge_copy['gene_name_x'].isin(['GRK6'])#['HSP90B1'])#, 'PCMT1'])

# %%
sns.scatterplot(data=isoswitch_editsC_merge_copy[['gene_name_x','edit_logFC', 'dIF','hsp_annot']], x='edit_logFC', y='dIF', hue='hsp_annot', palette=['grey', '#F27D18'], linewidth=0)
plt.xlim(-3, 3)
plt.ylim(-0.4, 0.4)
#plt.axhline(0, linestyle='dashed', color='lightgrey')
plt.axhline(0.1, linestyle='dashed', color='darkgrey')
plt.axhline(-0.1, linestyle='dashed', color='darkgrey')

#plt.axvline(0, linestyle='dashed', color='lightgrey')
plt.axvline(1, linestyle='dashed', color='darkgrey')
plt.axvline(-1, linestyle='dashed', color='darkgrey')
for i, point in isoswitch_editsC_merge_copy[isoswitch_editsC_merge_copy['hsp_annot']==True].iterrows():
        plt.text(point['edit_logFC']+.03, point['dIF'], str(point['gene_name_x']))
plt.legend([])
# plt.savefig(os.path.join(fig_path,'fig4/splicing_edit_overlay_GRK6.png'))
# plt.savefig(os.path.join(fig_path,'fig4/splicing_edit_overlay_GRK6.svg'))
# plt.savefig(os.path.join(fig_path,'fig4/splicing_edit_overlay_GRK6.jpg'))

# %%
isoswitch_editsC_merge[(np.abs(isoswitch_editsC_merge['dIF']) <0.1)][['gene_name_x','edit_logFC', 'dIF']]
# Out:
#                   gene_name_x  edit_logFC      dIF
# ENST00000672715.1         AK2    0.473931  0.01395
# ENST00000649295.1       PCMT1    0.000000 -0.05330
# ENST00000681941.1     HSP90B1   -1.584963 -0.02515

# %%
for g in set(isoswitch_editsC_merge['gene_name_x'].tolist()):
    print(g)
# Out:
# PCMT1
# PRPF40A
# BCCIP
# SEPTIN11
# ITGA3
# PHF19
# ATP5IF1
# IDS
# TGM2
# CUL4A
# GRB2
# WDR33
# AK2
# BUB3
# NECTIN2
# KPNB1
# H2AZ2
# APH1A
# CENPN
# MKRN1
# KRR1
# IL11
# HSP90B1
# TSC22D4
# GRK6
# TUBGCP2
# RBCK1

# %%
# for t in list(isoswitch_editsC_merge[isoswitch_editsC_merge['switchConsequencesGene'] == True].sort_values(by='gene_name_x').index):
#     sns.boxplot(pd.DataFrame([['NT', isoswitch_editsC_merge.loc[t,'editsC_NT_rep1'], isoswitch_editsC_merge.loc[t,'editsC_NT_rep2']], ['COCL2', isoswitch_editsC_merge.loc[t,'editsC_COCL2_rep1'], isoswitch_editsC_merge.loc[t,'editsC_COCL2_rep2']]]).set_index(0).T)
#     sns.stripplot(pd.DataFrame([['NT', isoswitch_editsC_merge.loc[t,'editsC_NT_rep1'], isoswitch_editsC_merge.loc[t,'editsC_NT_rep2']], ['COCL2', isoswitch_editsC_merge.loc[t,'editsC_COCL2_rep1'], isoswitch_editsC_merge.loc[t,'editsC_COCL2_rep2']]]).set_index(0).T)
#     plt.title(f'{t}_{isoswitch_editsC_merge.loc[t,"gene_name_x"]}')
#     plt.show()

# %%
annotated_transcript_editsC_copy[(annotated_transcript_editsC_copy['gene_name']=='GRK6')]
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENST00000507633.5         0.009569        0.012759           0.031898
# ENST00000355472.10        0.028466        0.023875           0.019284
#
#                     editsC_COCL2_rep2 gene_name transcript_type  \
# ENST00000507633.5            0.023923      GRK6  protein_coding
# ENST00000355472.10           0.020202      GRK6  protein_coding
#
#                     231_NT_rep1_count   Length  231_NT_rep1_RPKM  \
# ENST00000507633.5                55.0   9940.0          3.921474
# ENST00000355472.10              317.0  16215.0         13.855280
#
#                     231_cocl2_rep1_count  ...    pvalue      padj   NT_mean  \
# ENST00000507633.5                   99.0  ...  0.023164  0.073892  0.011164
# ENST00000355472.10                 207.0  ...  0.061335  0.140172  0.026171
#
#                     COCL2_mean  shortened_transcript_id  NT_RPKM_mean  \
# ...

# %%
annotated_transcript_editsC_copy[(annotated_transcript_editsC_copy['gene_name']=='PCMT1')].loc['ENST00000367384.7', 'ttest_pval']
# Out:
# 0.0

# %%
annotated_transcript_editsC_copy[(annotated_transcript_editsC_copy['gene_name']=='PCMT1')].index.tolist()
# Out:
# ['ENST00000367378.6', 'ENST00000367384.7', 'ENST00000649295.1']

# %%
annotated_transcript_editsC_copy
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENST00000370406.8         0.000000        0.002066           0.012397
# ENST00000392508.2         0.000000        0.001883           0.003766
# ENST00000611119.4         0.000000        0.000746           0.005224
# ENST00000442528.2         0.001576        0.000788           0.009456
# ENST00000222402.8         0.000000        0.000879           0.004394
# ...                            ...             ...                ...
# ENST00000373491.3         0.013393        0.004464           0.002232
# ENST00000397066.9         0.003836        0.000548           0.000000
# ENST00000331134.11        0.005069        0.005069           0.000461
# ENST00000409140.8         0.007439        0.004251           0.001063
# ENST00000327367.9         0.003880        0.001455           0.000000
#
#                     editsC_COCL2_rep2 gene_name transcript_type  \
# ...

# %%
import itertools

# %%
def get_viz_files_transcript(gname, iso_list, filePath):
    viz_out = '/tscc/nfs/home/pjaganna1/scratch/sshfs_connect'
    print('#!/bin/bash')
    print()
    print('module load samtools')
    for i in iso_list:
        for rep in ['rep1', 'rep2']:
            keep_edits_wt[rep][keep_edits_wt[rep]['transcript_id']==i][[0,1,2,3,4,5]].to_csv(os.path.join(viz_out,f'231_CDS_{gname}_wt_{rep}_{i}_.bed'), sep='\t', header=None, index=False)
            keep_edits_cocl2[rep][keep_edits_cocl2[rep]['transcript_id']==i][[0,1,2,3,4,5]].to_csv(os.path.join(viz_out,f'231_CDS_{gname}_cocl2_{rep}_{i}.bed'), sep='\t', header=None, index=False)
    for sample_dict in [sample_dict_wt, sample_dict_cocl2]:
        for rep in ['rep1', 'rep2']:
            infile = os.path.join(working_dir, f'{sample_dict[rep]}/output_dir/split_bam_{sample_dict[rep]}')
            split_dictionary = pd.read_pickle(infile)
            for i in iso_list:
                for s in split_dictionary:
                    if i in split_dictionary[s]['isoform'].tolist():
                        print("cp " + os.path.join(working_dir, f'{sample_dict[rep]}/output_dir/{s}.sorted.bam ') + '/tscc/nfs/home/pjaganna1/scratch/sshfs_connect/' + f'CDS_{gname}_{sample_dict[rep]}_{i}.sorted.bam')
                        print('samtools index ' + '/tscc/nfs/home/pjaganna1/scratch/sshfs_connect/' + f'CDS_{gname}_{sample_dict[rep]}_{i}.sorted.bam')
    
    print('module unload samtools')
    gene_toplot = annotated_transcript_editsC_copy[(annotated_transcript_editsC_copy['gene_name']==gname) & (annotated_transcript_editsC_copy.index.isin(iso_list))]

    # for i in list(itertools.combinations(iso_list, 2)):
    #     i1 = i[0]
    #     i2 = i[1]
    #     fig, axes = plt.subplots(2,1, sharey=False, figsize=(2,6),sharex=True)
    #     sns.barplot(pd.DataFrame([[f'{i[0]}', gene_toplot.loc[i[0],'editsC_NT_rep1'], gene_toplot.loc[i[0],'editsC_NT_rep2']], [f'{i[1]}', gene_toplot.loc[i[1],'editsC_NT_rep1'], gene_toplot.loc[i[1],'editsC_NT_rep2']]]).set_index(0).T, ax=axes[0], palette=['#FE9920', '#028090'])
    #     sns.barplot(pd.DataFrame([[f'{i[0]}', gene_toplot.loc[i[0],'231_NT_rep1_RPKM'], gene_toplot.loc[i[0],'231_NT_rep2_RPKM']], [f'{i[1]}', gene_toplot.loc[i[1],'231_NT_rep1_RPKM'], gene_toplot.loc[i[1],'231_NT_rep2_RPKM']]]).set_index(0).T, ax=axes[1], palette=['#FE9920', '#028090'])
    #     fig.suptitle(f'{gname} {i}')
    #     axes[0].set_ylabel('editsC')
    #     axes[1].set_ylabel('RPKM')
    #     plt.suptitle('NT')
    #     # plt.savefig(os.path.join(fig_path,'fig3/PCNP_APOBEC1.png'))
    #     # plt.savefig(os.path.join(fig_path,'fig3/PCNP_APOBEC1.svg'))
    #     # plt.savefig(os.path.join(fig_path,'fig3/PCNP_APOBEC1.jpg'))
    #     plt.show()
    
    #     fig, axes = plt.subplots(2, 1, sharey=False, figsize=(2,6),sharex=True)
    #     sns.barplot(pd.DataFrame([[f'{i[0]}', gene_toplot.loc[i[0],'editsC_COCL2_rep1'], gene_toplot.loc[i[0],'editsC_COCL2_rep2']], [f'{i[1]}', gene_toplot.loc[i[1],'editsC_COCL2_rep1'], gene_toplot.loc[i[1],'editsC_COCL2_rep2']]]).set_index(0).T, ax=axes[0], palette=['#FE9920', '#028090'])
    #     sns.barplot(pd.DataFrame([[f'{i[0]}', gene_toplot.loc[i[0],'231_cocl2_rep1_RPKM'], gene_toplot.loc[i[0],'231_cocl2_rep2_RPKM']], [f'{i[1]}', gene_toplot.loc[i[1],'231_cocl2_rep1_RPKM'], gene_toplot.loc[i[1],'231_cocl2_rep2_RPKM']]]).set_index(0).T, ax=axes[1], palette=['#FE9920', '#028090'])
    #     axes[0].set_ylabel('editsC')
    #     axes[1].set_ylabel('RPKM')
    #     plt.suptitle('COCL2')
    #     # plt.savefig(os.path.join(fig_path,'fig3/PCNP_RiboSTAMP.png'))
    #     # plt.savefig(os.path.join(fig_path,'fig3/PCNP_RiboSTAMP.svg'))
    #     # plt.savefig(os.path.join(fig_path,'fig3/PCNP_RiboSTAMP.jpg'))


    for i in list(itertools.combinations(iso_list, 2)):
        i1 = i[0]
        i2 = i[1]
        fig, axes = plt.subplots(1,2,  figsize=(3,3),sharey=True)#, sharey=True, figsize=(4,6),sharex=True)
        sns.barplot(pd.DataFrame([['NT', gene_toplot.loc[i[0],'editsC_NT_rep1'], gene_toplot.loc[i[0],'editsC_NT_rep2']], ['COCL2', gene_toplot.loc[i[0],'editsC_COCL2_rep1'], gene_toplot.loc[i[0],'editsC_COCL2_rep2']]]).set_index(0).T, ax=axes[0], palette=custom_palette[:2])
        sns.barplot(pd.DataFrame([['NT', gene_toplot.loc[i[1],'editsC_NT_rep1'], gene_toplot.loc[i[1],'editsC_NT_rep2']], ['COCL2', gene_toplot.loc[i[1],'editsC_COCL2_rep1'], gene_toplot.loc[i[1],'editsC_COCL2_rep2']]]).set_index(0).T, ax=axes[1], palette=custom_palette[:2])
        axes[0].set_ylabel('editsC')
        #axes[0].set_yscale('log')
        axes[0].set_title(f'{i[0]}')
        axes[1].set_title(f'{i[1]}')
        plt.suptitle('editsC')
        
        plt.savefig(os.path.join(fig_path,f'{filePath}_editsC.png'))
        plt.savefig(os.path.join(fig_path,f'{filePath}_editsC.jpg'))
        plt.savefig(os.path.join(fig_path,f'{filePath}_editsC.svg'))
        plt.show()
    
        fig, axes = plt.subplots(1,2,  figsize=(3,3),sharey=True)
        
        sns.barplot(pd.DataFrame([['NT', gene_toplot.loc[i[0],'231_NT_rep1_RPKM'], gene_toplot.loc[i[0],'231_NT_rep2_RPKM']], ['COCL2', gene_toplot.loc[i[0],'231_cocl2_rep1_RPKM'], gene_toplot.loc[i[0],'231_cocl2_rep2_RPKM']]]).set_index(0).T, ax=axes[0], palette=custom_palette[:2])
        sns.barplot(pd.DataFrame([['NT', gene_toplot.loc[i[1],'231_NT_rep1_RPKM'], gene_toplot.loc[i[1],'231_NT_rep2_RPKM']], ['COCL2', gene_toplot.loc[i[1],'231_cocl2_rep1_RPKM'], gene_toplot.loc[i[1],'231_cocl2_rep2_RPKM']]]).set_index(0).T, ax=axes[1], palette=custom_palette[:2])
        axes[0].set_ylabel('editsC')
        axes[0].set_ylabel('RPKM')
        axes[0].set_title(f'{i[0]}')
        axes[1].set_title(f'{i[1]}')
        plt.suptitle('RPKM')
        # plt.savefig(os.path.join(fig_path,f'{filePath}_RPKM.png'))
        # plt.savefig(os.path.join(fig_path,f'{filePath}_RPKM.jpg'))
        # plt.savefig(os.path.join(fig_path,f'{filePath}_RPKM.svg'))

# %%
get_viz_files_transcript('HSP90B1', ['ENST00000299767.10', 'ENST00000681941.1'], 'fig4/HSP90B1')

# %%
get_viz_files_transcript('PCMT1', ['ENST00000367378.6', 'ENST00000367384.7'], 'fig4/PCMT1')

# %%
get_viz_files_transcript('GRK6', ['ENST00000507633.5', 'ENST00000355472.10'], 'fig4/GRK6')

# %%
isoswitch_biomech = pd.read_csv('/tscc/nfs/home/pjaganna1/projects/STAMP/stamp_v3_pipeline/notebooks/231_data/diffsplice/IsoSwitch_AS_biomechanism_out.txt', sep='\t')

# %%
all_tts = isoswitch_biomech[(isoswitch_biomech['isoformsDifferent']==True) & (isoswitch_biomech['featureCompared']=='tts')]

# %%
all_tts_set = set(all_tts['isoformUpregulated'].tolist() + all_tts['isoformDownregulated'].tolist())

# %%
sns.scatterplot(data=isoswitch_editsC_merge_copy[isoswitch_editsC_merge_copy.index.isin(all_tts_set)][['gene_name_x','edit_logFC', 'dIF','hsp_annot']], x='edit_logFC', y='dIF', hue='hsp_annot', palette=['grey', '#F27D18'], linewidth=0)
plt.xlim(-3, 3)
plt.ylim(-0.4, 0.4)
#plt.axhline(0, linestyle='dashed', color='lightgrey')
plt.axhline(0.1, linestyle='dashed', color='darkgrey')
plt.axhline(-0.1, linestyle='dashed', color='darkgrey')

#plt.axvline(0, linestyle='dashed', color='lightgrey')
plt.axvline(1, linestyle='dashed', color='darkgrey')
plt.axvline(-1, linestyle='dashed', color='darkgrey')
for i, point in isoswitch_editsC_merge_copy[isoswitch_editsC_merge_copy['hsp_annot']==True].iterrows():
        plt.text(point['edit_logFC']+.03, point['dIF'], str(point['gene_name_x']))
plt.legend([])
plt.savefig(os.path.join(fig_path,'fig5/splicing_edit_ttsonly_overlay_GRK6.png'))
plt.savefig(os.path.join(fig_path,'fig5/splicing_edit_ttsonly_overlay_GRK6.svg'))
plt.savefig(os.path.join(fig_path,'fig5/splicing_edit_ttsonly_overlay_GRK6.jpg'))

# %%
isoswitch_biomech.dropna(subset='isoformsDifferent')['switchConsequence'].value_counts()
# Out:
# switchConsequence
# Tts more upstream      18
# Tss more downstream     6
# Tts more downstream     5
# Tss more upstream       4
# Name: count, dtype: int64

# %%
isoswitch_biomech[isoswitch_biomech['isoformsDifferent']==True]['featureCompared'].value_counts()
# Out:
# featureCompared
# tts                 23
# intron_structure    11
# tss                 10
# Name: count, dtype: int64

# %%
annotated_transcript_editsC_copy

# %%
tts_switch = isoswitch_biomech[(isoswitch_biomech['isoformsDifferent']==True) & (isoswitch_biomech['featureCompared']=='tts')]

# %%
tts_up_up = tts_switch[tts_switch['switchConsequence']=='Tts more upstream']['isoformUpregulated'].tolist()
tts_up_down = tts_switch[tts_switch['switchConsequence']=='Tts more upstream']['isoformDownregulated'].tolist()

# %%
gtf_file

# %%
print(len(tts_up_up), len(tts_up_down))

# %%
fig, axes = plt.subplots(1,1,  figsize=(2,3),sharey=True)

tts_up_editsC = annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(tts_up_up)]
tts_up_editsC['switch'] ='Upregulated Isoform'
print(tts_up_editsC.shape[0])

tts_down_editsC = annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(tts_up_down)]
tts_down_editsC['switch'] ='Downregulated Isoform'
print(tts_down_editsC.shape[0])

sns.boxplot(pd.concat([tts_up_editsC, tts_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette)
sns.stripplot(pd.concat([tts_up_editsC, tts_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette)


# sns.violinplot(annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(tts_up_up)]['edit_logFC'])
# sns.violinplot(annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(tts_up_down)]['edit_logFC'])

# %%
pd.concat([tts_up_editsC, tts_down_editsC])[pd.concat([tts_up_editsC, tts_down_editsC])['gene_name']=='GRK6']

# %%
tts_down_up = tts_switch[tts_switch['switchConsequence']=='Tts more downstream']['isoformUpregulated'].tolist()
tts_down_down = tts_switch[tts_switch['switchConsequence']=='Tts more downstream']['isoformDownregulated'].tolist()

# %%
fig, axes = plt.subplots(1,1,  figsize=(2,3),sharey=True)

tts_down_up_editsC = annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(tts_down_up)]
tts_down_up_editsC['switch'] ='Upregulated Isoform'
print(tts_down_up_editsC.shape[0])


tts_down_down_editsC = annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(tts_down_down)]
tts_down_down_editsC['switch'] ='Downregulated Isoform'
print(tts_down_down_editsC.shape[0])

sns.boxplot(pd.concat([tts_down_up_editsC, tts_down_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette)
sns.stripplot(pd.concat([tts_down_up_editsC, tts_down_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette)


# sns.violinplot(annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(tts_up_up)]['edit_logFC'])
# sns.violinplot(annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(tts_up_down)]['edit_logFC'])

# %%
intron_switch = isoswitch_biomech[(isoswitch_biomech['isoformsDifferent']==True) & (isoswitch_biomech['featureCompared']=='intron_structure')]

# %%
intron_switch_up = intron_switch['isoformUpregulated'].tolist()
intron_switch_down = intron_switch['isoformDownregulated'].tolist()

# %%
fig, axes = plt.subplots(1,1,  figsize=(2,3),sharey=True)

intron_up_editsC = annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(intron_switch_up)]
intron_up_editsC['switch'] = 'Upregulated Isoform'
print(intron_up_editsC.shape[0])

intron_down_editsC = annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(intron_switch_down)]
intron_down_editsC['switch'] ='Downregulated Isoform'
print(intron_down_editsC.shape[0])

sns.boxplot(pd.concat([intron_up_editsC, intron_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette)
sns.stripplot(pd.concat([intron_up_editsC, intron_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette)


# sns.violinplot(annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(tts_up_up)]['edit_logFC'])
# sns.violinplot(annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(tts_up_down)]['edit_logFC'])
# Out:
# 7
# 10
# /tmp/ipykernel_1461940/2195563725.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   intron_up_editsC['switch'] = 'Upregulated Isoform'
# /tmp/ipykernel_1461940/2195563725.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   intron_down_editsC['switch'] ='Downregulated Isoform'
# /tmp/ipykernel_1461940/2195563725.py:11: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
# ...

# %%
tss_switch = isoswitch_biomech[(isoswitch_biomech['isoformsDifferent']==True) & (isoswitch_biomech['featureCompared']=='tss')]

# %%
tss_up_up = tss_switch[tss_switch['switchConsequence']=='Tss more upstream']['isoformUpregulated'].tolist()
tss_up_down = tss_switch[tss_switch['switchConsequence']=='Tss more upstream']['isoformDownregulated'].tolist()

# %%
fig, axes = plt.subplots(1,1,  figsize=(2,3),sharey=True)

tss_up_editsC = annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(tss_up_up)]
tss_up_editsC['switch'] ='Upregulated Isoform'

tss_down_editsC = annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(tss_up_down)]
tss_down_editsC['switch'] ='Downregulated Isoform'

sns.boxplot(pd.concat([tts_down_up_editsC, tts_down_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette)
sns.stripplot(pd.concat([tts_down_up_editsC, tts_down_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette)



sns.boxplot(pd.concat([tss_up_editsC, tss_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette)
sns.stripplot(pd.concat([tss_up_editsC, tss_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette)
# Out:
# /tmp/ipykernel_1461940/1918052489.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tss_up_editsC['switch'] ='Upregulated Isoform'
# /tmp/ipykernel_1461940/1918052489.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tss_down_editsC['switch'] ='Downregulated Isoform'
# /tmp/ipykernel_1461940/1918052489.py:9: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
# ...

# %%
tss_down_up = tss_switch[tss_switch['switchConsequence']=='Tss more downstream']['isoformUpregulated'].tolist()
tss_down_down = tss_switch[tss_switch['switchConsequence']=='Tss more downstream']['isoformDownregulated'].tolist()

# %%
fig, axes = plt.subplots(1,1,  figsize=(2,3),sharey=True)

tss_down_up_editsC = annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(tss_down_up)]
tss_down_up_editsC['switch'] ='Upregulated Isoform'

tss_down_down_editsC = annotated_transcript_editsC_copy[annotated_transcript_editsC_copy.index.isin(tss_down_down)]
tss_down_down_editsC['switch'] ='Downregulated Isoform'

sns.boxplot(pd.concat([tss_down_up_editsC, tss_down_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette)
sns.stripplot(pd.concat([tss_down_up_editsC, tss_down_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette)
# Out:
# /tmp/ipykernel_1461940/2131760250.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tss_down_up_editsC['switch'] ='Upregulated Isoform'
# /tmp/ipykernel_1461940/2131760250.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tss_down_down_editsC['switch'] ='Downregulated Isoform'
# /tmp/ipykernel_1461940/2131760250.py:9: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
# ...

# %%
print(stats.ranksums(tts_up_editsC['edit_logFC'], tts_down_editsC['edit_logFC']))
# Out:
# RanksumsResult(statistic=4.066981206552813, pvalue=4.762608227005961e-05)

# %%
def assign_stars(pval):
    if pval <0.001:
        return '***'
    elif pval <0.01:
        return '**'
    elif pval <0.05:
        return '*'
    else:
        return 'ns'

# %%
fig, axes = plt.subplots(1,5,  figsize=(8,4),sharey=True)

sns.boxplot(pd.concat([tts_up_editsC, tts_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', ax=axes[0], palette=custom_palette[4:6])
sns.stripplot(pd.concat([tts_up_editsC, tts_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette, ax=axes[0])
axes[0].text(0, 2,f'n={tts_up_editsC.shape[0]}')
axes[0].text(1, 2,f'n={tts_down_editsC.shape[0]}')
axes[0].text(0.5, 2.5,assign_stars(stats.ranksums(tts_up_editsC['edit_logFC'], tts_down_editsC['edit_logFC'])[1]))

sns.boxplot(pd.concat([tts_down_up_editsC, tts_down_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette[4:6], ax=axes[1])
sns.stripplot(pd.concat([tts_down_up_editsC, tts_down_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette, ax=axes[1])
axes[1].text(0, 2,f'n={tts_down_up_editsC.shape[0]}')
axes[1].text(1, 2,f'n={tts_down_down_editsC.shape[0]}')
print(stats.ranksums(tts_down_up_editsC['edit_logFC'], tts_down_down_editsC['edit_logFC']))
axes[1].text(0.5, 2.5,assign_stars(stats.ranksums(tts_down_up_editsC['edit_logFC'], tts_down_down_editsC['edit_logFC'])[1]))


sns.boxplot(pd.concat([tss_up_editsC, tss_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette[4:6], ax=axes[2])
sns.stripplot(pd.concat([tss_up_editsC, tss_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette, ax=axes[2])
axes[2].text(0, 2,f'n={tss_up_editsC.shape[0]}')
axes[2].text(1, 2,f'n={tss_down_editsC.shape[0]}')
print(stats.ranksums(tss_up_editsC['edit_logFC'], tss_down_editsC['edit_logFC']))
axes[2].text(0.5, 2.5,assign_stars(stats.ranksums(tss_up_editsC['edit_logFC'], tss_down_editsC['edit_logFC'])[1]))


sns.boxplot(pd.concat([tss_down_up_editsC, tss_down_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette[4:6], ax=axes[3])
sns.stripplot(pd.concat([tss_down_up_editsC, tss_down_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette, ax=axes[3])
axes[3].text(0, 2,f'n={tss_down_up_editsC.shape[0]}')
axes[3].text(1, 2,f'n={tss_down_down_editsC.shape[0]}')
print(stats.ranksums(tss_down_up_editsC['edit_logFC'], tss_down_down_editsC['edit_logFC']))
axes[3].text(0.5, 2.5,assign_stars(stats.ranksums(tss_down_up_editsC['edit_logFC'], tss_down_down_editsC['edit_logFC'])[1]))


sns.boxplot(pd.concat([intron_up_editsC, intron_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette[4:6], ax=axes[4])
sns.stripplot(pd.concat([intron_up_editsC, intron_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette, ax=axes[4])
axes[4].text(0, 2,f'n={intron_up_editsC.shape[0]}')
axes[4].text(1, 2,f'n={intron_down_editsC.shape[0]}')
print(stats.ranksums(intron_up_editsC['edit_logFC'], intron_down_editsC['edit_logFC']))
axes[4].text(0.5, 2.5,assign_stars(stats.ranksums(intron_up_editsC['edit_logFC'], intron_down_editsC['edit_logFC'])[1]))



axes[0].set_title('TTS Upstream')
axes[1].set_title('TTS Downstream')

axes[2].set_title('TSS Upstream')
axes[3].set_title('TSS Downstream') 
axes[4].set_title('Intron Structure')

plt.ylim(-3, 3)
plt.savefig(os.path.join(fig_path,'fig4/AS_type_difeditsC.png'))
plt.savefig(os.path.join(fig_path,'fig4/AS_type_difeditsC.jpg'))
plt.savefig(os.path.join(fig_path,'fig4/AS_type_difeditsC.svg'))
#plt.axhline(1)
# Out:
# RanksumsResult(statistic=2.6111648393354674, pvalue=0.009023438818080326)
# /tmp/ipykernel_1461940/2040755737.py:4: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.stripplot(pd.concat([tts_up_editsC, tts_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette, ax=axes[0])
# /tmp/ipykernel_1461940/2040755737.py:10: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.stripplot(pd.concat([tts_down_up_editsC, tts_down_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette, ax=axes[1])
# /tmp/ipykernel_1461940/2040755737.py:18: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.stripplot(pd.concat([tss_up_editsC, tss_down_editsC])[['edit_logFC', 'switch']], x='switch', y='edit_logFC', hue='switch', palette=custom_palette, ax=axes[2])
# ...

# %%
tts_down_down
# Out:
# ['ENST00000368759.5',
#  'ENST00000368865.9',
#  'ENST00000305850.10',
#  'ENST00000367384.7',
#  'ENST00000373896.8']

# %%
annotated_transcript_editsC_copy.dropna()
# Out:
#                     editsC_NT_rep1  editsC_NT_rep2  editsC_COCL2_rep1  \
# ENST00000370406.8         0.000000        0.002066           0.012397
# ENST00000392508.2         0.000000        0.001883           0.003766
# ENST00000611119.4         0.000000        0.000746           0.005224
# ENST00000442528.2         0.001576        0.000788           0.009456
# ENST00000222402.8         0.000000        0.000879           0.004394
# ...                            ...             ...                ...
# ENST00000373491.3         0.013393        0.004464           0.002232
# ENST00000397066.9         0.003836        0.000548           0.000000
# ENST00000331134.11        0.005069        0.005069           0.000461
# ENST00000409140.8         0.007439        0.004251           0.001063
# ENST00000327367.9         0.003880        0.001455           0.000000
#
#                     editsC_COCL2_rep2 gene_name transcript_type  \
# ...
